# %% [markdown]
# ## 引包

# %%
import os
import cv2
import io
import glob
import random
import numpy as np
import pandas as pd
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint,ReduceLROnPlateau
from tensorflow import keras
from tensorflow.keras import layers, models, Sequential, backend
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization, Activation, GlobalAveragePooling2D
from tensorflow.keras.layers import Concatenate, Lambda, Input, ZeroPadding2D, AveragePooling2D
from keras.utils.np_utils import to_categorical

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix

import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
import ipywidgets as widgets
from IPython.display import clear_output,display

#调用GPU方法
config = tf.compat.v1.ConfigProto(gpu_options=tf.compat.v1.GPUOptions(allow_growth=True))
sess = tf.compat.v1.Session(config=config)
# 选择编号为0的GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"#我的笔记本只有一块GPU，编号是0，所以这里调用编号为0的GPU


SEED=6
tf.random.set_seed(SEED)
# Out:
# 2022-12-17 14:03:07.373007: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-17 14:03:08.309694: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22320 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:d1:00.0, compute capability: 8.6

# %% [markdown]
# ## 加载数据

# %%
x_train_savepath = '../../../../autodl-tmp/X_train.npy'
y_train_savepath = '../../../../autodl-tmp/Y_train.npy'
x_test_savepath = '../../../../autodl-tmp/X_test.npy'
y_test_savepath = '../../../../autodl-tmp/Y_test.npy'

def load_data():
    #如果数据集数组文件存在, 就直接载入
    if os.path.exists(x_train_savepath) and os.path.exists(y_train_savepath) and os.path.exists(
            x_test_savepath) and os.path.exists(y_test_savepath):
        X_train = np.load(x_train_savepath)
        Y_train = np.load(y_train_savepath)
        X_test = np.load(x_test_savepath)
        Y_test = np.load(y_test_savepath)
    return X_train, Y_train, X_test, Y_test


X_train, Y_train, X_test, Y_test = load_data()

# %%
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("Y_train:", Y_train.shape)
print("Y_test:", Y_test.shape)
# Out:
# X_train: (15360, 224, 224, 3)
# X_test: (3840, 224, 224, 3)
# Y_train: (15360, 2)
# Y_test: (3840, 2)

# %% [markdown]
# ## 搭建模型DenseNet121

# %%
def conv_block(x, nb_filter, dropout_rate=None, name=None):
    
    inter_channel = nb_filter*4

    # 1x1 convolution， 
    # epsilon 将小浮点数添加到方差以避免被零除
    # data_format="channels_first"，(batch_size, channels,height, width)则在BatchNormalization中设置axis=1，默认是channels_last，则设置axis=3
    x = BatchNormalization(epsilon=1.1e-5, axis=3, name=name+'_bn1')(x)
    x = Activation('relu', name=name+'_relu1')(x)
    x = Conv2D(inter_channel, 1, 1, name=name+'_conv1', use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    # 3x3 convolution
    x = BatchNormalization(epsilon=1.1e-5, axis=3, name=name+'_bn2')(x)
    x = Activation('relu', name=name+'_relu2')(x)
    x = ZeroPadding2D((1, 1), name=name+'_zeropadding2')(x)
    x = Conv2D(nb_filter, 3, 1, name=name+'_conv2', use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    return x

def dense_block(x, stage, nb_layers, nb_filter, growth_rate, dropout_rate=None, 
                grow_nb_filters=True, name =None):

    concat_feat = x # store the last layer output

    for i in range(nb_layers):
        
        branch = i+1
        x =conv_block(concat_feat, growth_rate, dropout_rate, name=name+str(stage)+'_block'+str(branch)) # 在参考的基础，修改的地方这里应该是相同的growth_rate=32
        concat_feat = Concatenate(axis=3, name=name+str(stage)+'_block'+str(branch))([concat_feat, x])

        if grow_nb_filters:
            nb_filter += growth_rate

    return concat_feat, nb_filter



def transition_block (x,stage, nb_filter, compression=1.0, dropout_rate=None, name=None):

    x = BatchNormalization(epsilon=1.1e-5, axis=3, name=name+str(stage)+'_bn')(x)
    x = Activation('relu', name=name+str(stage)+'_relu')(x)
    
    x = Conv2D(int(nb_filter*compression), 1, 1, name=name+str(stage)+'_conv', use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)
    
    x = AveragePooling2D((2,2), strides=(2,2), name=name+str(stage)+'_pooling2d')(x)

    return x


def DenseNet(nb_dense_block=4, growth_rate=32, nb_filter=64, reduction=0.0, dropout_rate=0.0, weight_decay=1e-4, classes=1000, weights_path=None):

    compression = 1.0-reduction
    nb_filter=64
    nb_layers = [6, 12, 24, 16]  #For DenseNet-121
    
    img_input = Input(shape=(224,224,3))

    #initial convolution
    x = ZeroPadding2D((3, 3), name='conv1_zeropadding')(img_input)        # (3, 3)  s=1
    x = Conv2D(nb_filter, 7, 2, name='conv1', use_bias=False)(x)          # ====(7, 7)  s=2==== Conv2D
    x = BatchNormalization(epsilon=1.1e-5, axis=3, name='conv1_bn')(x)    
    x = Activation('relu', name='relu1')(x)
    x = ZeroPadding2D((1, 1), name='pool1_zeropadding')(x)                # (1, 1)  s=1
    x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1')(x)             # ====(3, 3 ) s=2==== MaxPooling

    #Dense block and Transition layer
    for block_id in range(nb_dense_block-1):
        stage = block_id+2 # start from 2
        x, nb_filter = dense_block(x, stage, nb_layers[block_id], nb_filter, growth_rate, 
        dropout_rate=dropout_rate, name='Dense')

        x = transition_block(x, stage, nb_filter, compression=compression, dropout_rate=dropout_rate, name='Trans')
        nb_filter *=compression
    
    final_stage = stage + 1
    x, nb_filter=dense_block(x, final_stage, nb_layers[-1], nb_filter, growth_rate, 
        dropout_rate=dropout_rate, name='Dense')

    # top layer
    x = BatchNormalization(name= 'final_conv_bn')(x)
    x = Activation('relu', name='final_act')(x)
    x = GlobalAveragePooling2D(name='final_pooling')(x)
    # x = Dense(classes, activation='softmax', name='fc')(x)

    model=models.Model(img_input, x, name='DenseNet')

    return model
    


conv_base = DenseNet(reduction=.5)

path_weights = "../../densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5"
conv_base.load_weights(path_weights)
conv_base.trainable = True

model=conv_base.output
model=tf.keras.layers.Dense(512,activation='relu')(model)
model=tf.keras.layers.Dropout(0.5)(model)
model=tf.keras.layers.Dense(2,activation="softmax")(model)
model=tf.keras.models.Model(inputs=conv_base.input,outputs=model)

model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
model.summary()

tensorboard = TensorBoard(log_dir="AD-CN-Freeze-1")
checkpoint = ModelCheckpoint("AD-CN-Freeze-1.h5", 
                            monitor='val_accuracy', 
                            mode = "auto", 
                            verbose = 1,
                            save_best_only =True)
# Out:
# 2022-12-17 14:03:24.337517: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22320 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:d1:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_zeropadding (ZeroPadding2 (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9408        conv1_zeropadding[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_zeropadding (ZeroPadding2 (None, 114, 114, 64) 0           relu1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           pool1_zeropadding[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_bn1 (BatchNormali (None, 56, 56, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_relu1 (Activation (None, 56, 56, 64)   0           Dense2_block1_bn1[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_conv1 (Conv2D)    (None, 56, 56, 128)  8192        Dense2_block1_relu1[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_bn2 (BatchNormali (None, 56, 56, 128)  512         Dense2_block1_conv1[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_relu2 (Activation (None, 56, 56, 128)  0           Dense2_block1_bn2[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_zeropadding2 (Zer (None, 58, 58, 128)  0           Dense2_block1_relu2[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_conv2 (Conv2D)    (None, 56, 56, 32)   36864       Dense2_block1_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense2_block1 (Concatenate)     (None, 56, 56, 96)   0           pool1[0][0]
#                                                                  Dense2_block1_conv2[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_bn1 (BatchNormali (None, 56, 56, 96)   384         Dense2_block1[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_relu1 (Activation (None, 56, 56, 96)   0           Dense2_block2_bn1[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_conv1 (Conv2D)    (None, 56, 56, 128)  12288       Dense2_block2_relu1[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_bn2 (BatchNormali (None, 56, 56, 128)  512         Dense2_block2_conv1[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_relu2 (Activation (None, 56, 56, 128)  0           Dense2_block2_bn2[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_zeropadding2 (Zer (None, 58, 58, 128)  0           Dense2_block2_relu2[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_conv2 (Conv2D)    (None, 56, 56, 32)   36864       Dense2_block2_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense2_block2 (Concatenate)     (None, 56, 56, 128)  0           Dense2_block1[0][0]
#                                                                  Dense2_block2_conv2[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_bn1 (BatchNormali (None, 56, 56, 128)  512         Dense2_block2[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_relu1 (Activation (None, 56, 56, 128)  0           Dense2_block3_bn1[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_conv1 (Conv2D)    (None, 56, 56, 128)  16384       Dense2_block3_relu1[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_bn2 (BatchNormali (None, 56, 56, 128)  512         Dense2_block3_conv1[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_relu2 (Activation (None, 56, 56, 128)  0           Dense2_block3_bn2[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_zeropadding2 (Zer (None, 58, 58, 128)  0           Dense2_block3_relu2[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_conv2 (Conv2D)    (None, 56, 56, 32)   36864       Dense2_block3_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense2_block3 (Concatenate)     (None, 56, 56, 160)  0           Dense2_block2[0][0]
#                                                                  Dense2_block3_conv2[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_bn1 (BatchNormali (None, 56, 56, 160)  640         Dense2_block3[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_relu1 (Activation (None, 56, 56, 160)  0           Dense2_block4_bn1[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_conv1 (Conv2D)    (None, 56, 56, 128)  20480       Dense2_block4_relu1[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_bn2 (BatchNormali (None, 56, 56, 128)  512         Dense2_block4_conv1[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_relu2 (Activation (None, 56, 56, 128)  0           Dense2_block4_bn2[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_zeropadding2 (Zer (None, 58, 58, 128)  0           Dense2_block4_relu2[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_conv2 (Conv2D)    (None, 56, 56, 32)   36864       Dense2_block4_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense2_block4 (Concatenate)     (None, 56, 56, 192)  0           Dense2_block3[0][0]
#                                                                  Dense2_block4_conv2[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_bn1 (BatchNormali (None, 56, 56, 192)  768         Dense2_block4[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_relu1 (Activation (None, 56, 56, 192)  0           Dense2_block5_bn1[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_conv1 (Conv2D)    (None, 56, 56, 128)  24576       Dense2_block5_relu1[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_bn2 (BatchNormali (None, 56, 56, 128)  512         Dense2_block5_conv1[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_relu2 (Activation (None, 56, 56, 128)  0           Dense2_block5_bn2[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_zeropadding2 (Zer (None, 58, 58, 128)  0           Dense2_block5_relu2[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_conv2 (Conv2D)    (None, 56, 56, 32)   36864       Dense2_block5_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense2_block5 (Concatenate)     (None, 56, 56, 224)  0           Dense2_block4[0][0]
#                                                                  Dense2_block5_conv2[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_bn1 (BatchNormali (None, 56, 56, 224)  896         Dense2_block5[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_relu1 (Activation (None, 56, 56, 224)  0           Dense2_block6_bn1[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_conv1 (Conv2D)    (None, 56, 56, 128)  28672       Dense2_block6_relu1[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_bn2 (BatchNormali (None, 56, 56, 128)  512         Dense2_block6_conv1[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_relu2 (Activation (None, 56, 56, 128)  0           Dense2_block6_bn2[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_zeropadding2 (Zer (None, 58, 58, 128)  0           Dense2_block6_relu2[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_conv2 (Conv2D)    (None, 56, 56, 32)   36864       Dense2_block6_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense2_block6 (Concatenate)     (None, 56, 56, 256)  0           Dense2_block5[0][0]
#                                                                  Dense2_block6_conv2[0][0]
# __________________________________________________________________________________________________
# Trans2_bn (BatchNormalization)  (None, 56, 56, 256)  1024        Dense2_block6[0][0]
# __________________________________________________________________________________________________
# Trans2_relu (Activation)        (None, 56, 56, 256)  0           Trans2_bn[0][0]
# __________________________________________________________________________________________________
# Trans2_conv (Conv2D)            (None, 56, 56, 128)  32768       Trans2_relu[0][0]
# __________________________________________________________________________________________________
# Trans2_pooling2d (AveragePoolin (None, 28, 28, 128)  0           Trans2_conv[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_bn1 (BatchNormali (None, 28, 28, 128)  512         Trans2_pooling2d[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_relu1 (Activation (None, 28, 28, 128)  0           Dense3_block1_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_conv1 (Conv2D)    (None, 28, 28, 128)  16384       Dense3_block1_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block1_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block1_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block1_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block1_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense3_block1 (Concatenate)     (None, 28, 28, 160)  0           Trans2_pooling2d[0][0]
#                                                                  Dense3_block1_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_bn1 (BatchNormali (None, 28, 28, 160)  640         Dense3_block1[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_relu1 (Activation (None, 28, 28, 160)  0           Dense3_block2_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_conv1 (Conv2D)    (None, 28, 28, 128)  20480       Dense3_block2_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block2_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block2_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block2_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block2_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense3_block2 (Concatenate)     (None, 28, 28, 192)  0           Dense3_block1[0][0]
#                                                                  Dense3_block2_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_bn1 (BatchNormali (None, 28, 28, 192)  768         Dense3_block2[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_relu1 (Activation (None, 28, 28, 192)  0           Dense3_block3_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_conv1 (Conv2D)    (None, 28, 28, 128)  24576       Dense3_block3_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block3_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block3_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block3_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block3_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense3_block3 (Concatenate)     (None, 28, 28, 224)  0           Dense3_block2[0][0]
#                                                                  Dense3_block3_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_bn1 (BatchNormali (None, 28, 28, 224)  896         Dense3_block3[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_relu1 (Activation (None, 28, 28, 224)  0           Dense3_block4_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_conv1 (Conv2D)    (None, 28, 28, 128)  28672       Dense3_block4_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block4_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block4_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block4_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block4_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense3_block4 (Concatenate)     (None, 28, 28, 256)  0           Dense3_block3[0][0]
#                                                                  Dense3_block4_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_bn1 (BatchNormali (None, 28, 28, 256)  1024        Dense3_block4[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_relu1 (Activation (None, 28, 28, 256)  0           Dense3_block5_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_conv1 (Conv2D)    (None, 28, 28, 128)  32768       Dense3_block5_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block5_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block5_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block5_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block5_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense3_block5 (Concatenate)     (None, 28, 28, 288)  0           Dense3_block4[0][0]
#                                                                  Dense3_block5_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_bn1 (BatchNormali (None, 28, 28, 288)  1152        Dense3_block5[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_relu1 (Activation (None, 28, 28, 288)  0           Dense3_block6_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_conv1 (Conv2D)    (None, 28, 28, 128)  36864       Dense3_block6_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block6_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block6_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block6_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block6_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense3_block6 (Concatenate)     (None, 28, 28, 320)  0           Dense3_block5[0][0]
#                                                                  Dense3_block6_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_bn1 (BatchNormali (None, 28, 28, 320)  1280        Dense3_block6[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_relu1 (Activation (None, 28, 28, 320)  0           Dense3_block7_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_conv1 (Conv2D)    (None, 28, 28, 128)  40960       Dense3_block7_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block7_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block7_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block7_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block7_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense3_block7 (Concatenate)     (None, 28, 28, 352)  0           Dense3_block6[0][0]
#                                                                  Dense3_block7_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_bn1 (BatchNormali (None, 28, 28, 352)  1408        Dense3_block7[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_relu1 (Activation (None, 28, 28, 352)  0           Dense3_block8_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_conv1 (Conv2D)    (None, 28, 28, 128)  45056       Dense3_block8_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block8_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block8_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block8_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block8_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense3_block8 (Concatenate)     (None, 28, 28, 384)  0           Dense3_block7[0][0]
#                                                                  Dense3_block8_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_bn1 (BatchNormali (None, 28, 28, 384)  1536        Dense3_block8[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_relu1 (Activation (None, 28, 28, 384)  0           Dense3_block9_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_conv1 (Conv2D)    (None, 28, 28, 128)  49152       Dense3_block9_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block9_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block9_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block9_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block9_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense3_block9 (Concatenate)     (None, 28, 28, 416)  0           Dense3_block8[0][0]
#                                                                  Dense3_block9_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block10_bn1 (BatchNormal (None, 28, 28, 416)  1664        Dense3_block9[0][0]
# __________________________________________________________________________________________________
# Dense3_block10_relu1 (Activatio (None, 28, 28, 416)  0           Dense3_block10_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block10_conv1 (Conv2D)   (None, 28, 28, 128)  53248       Dense3_block10_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block10_bn2 (BatchNormal (None, 28, 28, 128)  512         Dense3_block10_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block10_relu2 (Activatio (None, 28, 28, 128)  0           Dense3_block10_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block10_zeropadding2 (Ze (None, 30, 30, 128)  0           Dense3_block10_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block10_conv2 (Conv2D)   (None, 28, 28, 32)   36864       Dense3_block10_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense3_block10 (Concatenate)    (None, 28, 28, 448)  0           Dense3_block9[0][0]
#                                                                  Dense3_block10_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block11_bn1 (BatchNormal (None, 28, 28, 448)  1792        Dense3_block10[0][0]
# __________________________________________________________________________________________________
# Dense3_block11_relu1 (Activatio (None, 28, 28, 448)  0           Dense3_block11_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block11_conv1 (Conv2D)   (None, 28, 28, 128)  57344       Dense3_block11_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block11_bn2 (BatchNormal (None, 28, 28, 128)  512         Dense3_block11_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block11_relu2 (Activatio (None, 28, 28, 128)  0           Dense3_block11_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block11_zeropadding2 (Ze (None, 30, 30, 128)  0           Dense3_block11_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block11_conv2 (Conv2D)   (None, 28, 28, 32)   36864       Dense3_block11_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense3_block11 (Concatenate)    (None, 28, 28, 480)  0           Dense3_block10[0][0]
#                                                                  Dense3_block11_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block12_bn1 (BatchNormal (None, 28, 28, 480)  1920        Dense3_block11[0][0]
# __________________________________________________________________________________________________
# Dense3_block12_relu1 (Activatio (None, 28, 28, 480)  0           Dense3_block12_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block12_conv1 (Conv2D)   (None, 28, 28, 128)  61440       Dense3_block12_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block12_bn2 (BatchNormal (None, 28, 28, 128)  512         Dense3_block12_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block12_relu2 (Activatio (None, 28, 28, 128)  0           Dense3_block12_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block12_zeropadding2 (Ze (None, 30, 30, 128)  0           Dense3_block12_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block12_conv2 (Conv2D)   (None, 28, 28, 32)   36864       Dense3_block12_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense3_block12 (Concatenate)    (None, 28, 28, 512)  0           Dense3_block11[0][0]
#                                                                  Dense3_block12_conv2[0][0]
# __________________________________________________________________________________________________
# Trans3_bn (BatchNormalization)  (None, 28, 28, 512)  2048        Dense3_block12[0][0]
# __________________________________________________________________________________________________
# Trans3_relu (Activation)        (None, 28, 28, 512)  0           Trans3_bn[0][0]
# __________________________________________________________________________________________________
# Trans3_conv (Conv2D)            (None, 28, 28, 256)  131072      Trans3_relu[0][0]
# __________________________________________________________________________________________________
# Trans3_pooling2d (AveragePoolin (None, 14, 14, 256)  0           Trans3_conv[0][0]
# __________________________________________________________________________________________________
# Dense4_block1_bn1 (BatchNormali (None, 14, 14, 256)  1024        Trans3_pooling2d[0][0]
# __________________________________________________________________________________________________
# Dense4_block1_relu1 (Activation (None, 14, 14, 256)  0           Dense4_block1_bn1[0][0]
# __________________________________________________________________________________________________
# Dense4_block1_conv1 (Conv2D)    (None, 14, 14, 128)  32768       Dense4_block1_relu1[0][0]
# __________________________________________________________________________________________________
# Dense4_block1_bn2 (BatchNormali (None, 14, 14, 128)  512         Dense4_block1_conv1[0][0]
# __________________________________________________________________________________________________
# Dense4_block1_relu2 (Activation (None, 14, 14, 128)  0           Dense4_block1_bn2[0][0]
# __________________________________________________________________________________________________
# Dense4_block1_zeropadding2 (Zer (None, 16, 16, 128)  0           Dense4_block1_relu2[0][0]
# __________________________________________________________________________________________________
# Dense4_block1_conv2 (Conv2D)    (None, 14, 14, 32)   36864       Dense4_block1_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense4_block1 (Concatenate)     (None, 14, 14, 288)  0           Trans3_pooling2d[0][0]
#                                                                  Dense4_block1_conv2[0][0]
# __________________________________________________________________________________________________
# Dense4_block2_bn1 (BatchNormali (None, 14, 14, 288)  1152        Dense4_block1[0][0]
# __________________________________________________________________________________________________
# Dense4_block2_relu1 (Activation (None, 14, 14, 288)  0           Dense4_block2_bn1[0][0]
# __________________________________________________________________________________________________
# Dense4_block2_conv1 (Conv2D)    (None, 14, 14, 128)  36864       Dense4_block2_relu1[0][0]
# __________________________________________________________________________________________________
# Dense4_block2_bn2 (BatchNormali (None, 14, 14, 128)  512         Dense4_block2_conv1[0][0]
# __________________________________________________________________________________________________
# Dense4_block2_relu2 (Activation (None, 14, 14, 128)  0           Dense4_block2_bn2[0][0]
# __________________________________________________________________________________________________
# Dense4_block2_zeropadding2 (Zer (None, 16, 16, 128)  0           Dense4_block2_relu2[0][0]
# __________________________________________________________________________________________________
# Dense4_block2_conv2 (Conv2D)    (None, 14, 14, 32)   36864       Dense4_block2_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense4_block2 (Concatenate)     (None, 14, 14, 320)  0           Dense4_block1[0][0]
#                                                                  Dense4_block2_conv2[0][0]
# __________________________________________________________________________________________________
# Dense4_block3_bn1 (BatchNormali (None, 14, 14, 320)  1280        Dense4_block2[0][0]
# __________________________________________________________________________________________________
# Dense4_block3_relu1 (Activation (None, 14, 14, 320)  0           Dense4_block3_bn1[0][0]
# __________________________________________________________________________________________________
# Dense4_block3_conv1 (Conv2D)    (None, 14, 14, 128)  40960       Dense4_block3_relu1[0][0]
# __________________________________________________________________________________________________
# Dense4_block3_bn2 (BatchNormali (None, 14, 14, 128)  512         Dense4_block3_conv1[0][0]
# __________________________________________________________________________________________________
# Dense4_block3_relu2 (Activation (None, 14, 14, 128)  0           Dense4_block3_bn2[0][0]
# __________________________________________________________________________________________________
# Dense4_block3_zeropadding2 (Zer (None, 16, 16, 128)  0           Dense4_block3_relu2[0][0]
# __________________________________________________________________________________________________
# Dense4_block3_conv2 (Conv2D)    (None, 14, 14, 32)   36864       Dense4_block3_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense4_block3 (Concatenate)     (None, 14, 14, 352)  0           Dense4_block2[0][0]
#                                                                  Dense4_block3_conv2[0][0]
# __________________________________________________________________________________________________
# Dense4_block4_bn1 (BatchNormali (None, 14, 14, 352)  1408        Dense4_block3[0][0]
# __________________________________________________________________________________________________
# Dense4_block4_relu1 (Activation (None, 14, 14, 352)  0           Dense4_block4_bn1[0][0]
# __________________________________________________________________________________________________
# Dense4_block4_conv1 (Conv2D)    (None, 14, 14, 128)  45056       Dense4_block4_relu1[0][0]
# __________________________________________________________________________________________________
# Dense4_block4_bn2 (BatchNormali (None, 14, 14, 128)  512         Dense4_block4_conv1[0][0]
# __________________________________________________________________________________________________
# Dense4_block4_relu2 (Activation (None, 14, 14, 128)  0           Dense4_block4_bn2[0][0]
# __________________________________________________________________________________________________
# Dense4_block4_zeropadding2 (Zer (None, 16, 16, 128)  0           Dense4_block4_relu2[0][0]
# __________________________________________________________________________________________________
# Dense4_block4_conv2 (Conv2D)    (None, 14, 14, 32)   36864       Dense4_block4_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense4_block4 (Concatenate)     (None, 14, 14, 384)  0           Dense4_block3[0][0]
#                                                                  Dense4_block4_conv2[0][0]
# __________________________________________________________________________________________________
# Dense4_block5_bn1 (BatchNormali (None, 14, 14, 384)  1536        Dense4_block4[0][0]
# __________________________________________________________________________________________________
# Dense4_block5_relu1 (Activation (None, 14, 14, 384)  0           Dense4_block5_bn1[0][0]
# __________________________________________________________________________________________________
# Dense4_block5_conv1 (Conv2D)    (None, 14, 14, 128)  49152       Dense4_block5_relu1[0][0]
# __________________________________________________________________________________________________
# Dense4_block5_bn2 (BatchNormali (None, 14, 14, 128)  512         Dense4_block5_conv1[0][0]
# __________________________________________________________________________________________________
# Dense4_block5_relu2 (Activation (None, 14, 14, 128)  0           Dense4_block5_bn2[0][0]
# __________________________________________________________________________________________________
# Dense4_block5_zeropadding2 (Zer (None, 16, 16, 128)  0           Dense4_block5_relu2[0][0]
# __________________________________________________________________________________________________
# Dense4_block5_conv2 (Conv2D)    (None, 14, 14, 32)   36864       Dense4_block5_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense4_block5 (Concatenate)     (None, 14, 14, 416)  0           Dense4_block4[0][0]
#                                                                  Dense4_block5_conv2[0][0]
# __________________________________________________________________________________________________
# Dense4_block6_bn1 (BatchNormali (None, 14, 14, 416)  1664        Dense4_block5[0][0]
# __________________________________________________________________________________________________
# Dense4_block6_relu1 (Activation (None, 14, 14, 416)  0           Dense4_block6_bn1[0][0]
# __________________________________________________________________________________________________
# Dense4_block6_conv1 (Conv2D)    (None, 14, 14, 128)  53248       Dense4_block6_relu1[0][0]
# __________________________________________________________________________________________________
# Dense4_block6_bn2 (BatchNormali (None, 14, 14, 128)  512         Dense4_block6_conv1[0][0]
# __________________________________________________________________________________________________
# Dense4_block6_relu2 (Activation (None, 14, 14, 128)  0           Dense4_block6_bn2[0][0]
# __________________________________________________________________________________________________
# Dense4_block6_zeropadding2 (Zer (None, 16, 16, 128)  0           Dense4_block6_relu2[0][0]
# __________________________________________________________________________________________________
# Dense4_block6_conv2 (Conv2D)    (None, 14, 14, 32)   36864       Dense4_block6_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense4_block6 (Concatenate)     (None, 14, 14, 448)  0           Dense4_block5[0][0]
#                                                                  Dense4_block6_conv2[0][0]
# __________________________________________________________________________________________________
# Dense4_block7_bn1 (BatchNormali (None, 14, 14, 448)  1792        Dense4_block6[0][0]
# __________________________________________________________________________________________________
# Dense4_block7_relu1 (Activation (None, 14, 14, 448)  0           Dense4_block7_bn1[0][0]
# __________________________________________________________________________________________________
# Dense4_block7_conv1 (Conv2D)    (None, 14, 14, 128)  57344       Dense4_block7_relu1[0][0]
# __________________________________________________________________________________________________
# Dense4_block7_bn2 (BatchNormali (None, 14, 14, 128)  512         Dense4_block7_conv1[0][0]
# __________________________________________________________________________________________________
# Dense4_block7_relu2 (Activation (None, 14, 14, 128)  0           Dense4_block7_bn2[0][0]
# __________________________________________________________________________________________________
# Dense4_block7_zeropadding2 (Zer (None, 16, 16, 128)  0           Dense4_block7_relu2[0][0]
# __________________________________________________________________________________________________
# Dense4_block7_conv2 (Conv2D)    (None, 14, 14, 32)   36864       Dense4_block7_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense4_block7 (Concatenate)     (None, 14, 14, 480)  0           Dense4_block6[0][0]
#                                                                  Dense4_block7_conv2[0][0]
# __________________________________________________________________________________________________
# Dense4_block8_bn1 (BatchNormali (None, 14, 14, 480)  1920        Dense4_block7[0][0]
# __________________________________________________________________________________________________
# Dense4_block8_relu1 (Activation (None, 14, 14, 480)  0           Dense4_block8_bn1[0][0]
# __________________________________________________________________________________________________
# Dense4_block8_conv1 (Conv2D)    (None, 14, 14, 128)  61440       Dense4_block8_relu1[0][0]
# __________________________________________________________________________________________________
# Dense4_block8_bn2 (BatchNormali (None, 14, 14, 128)  512         Dense4_block8_conv1[0][0]
# __________________________________________________________________________________________________
# Dense4_block8_relu2 (Activation (None, 14, 14, 128)  0           Dense4_block8_bn2[0][0]
# __________________________________________________________________________________________________
# Dense4_block8_zeropadding2 (Zer (None, 16, 16, 128)  0           Dense4_block8_relu2[0][0]
# __________________________________________________________________________________________________
# Dense4_block8_conv2 (Conv2D)    (None, 14, 14, 32)   36864       Dense4_block8_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense4_block8 (Concatenate)     (None, 14, 14, 512)  0           Dense4_block7[0][0]
#                                                                  Dense4_block8_conv2[0][0]
# __________________________________________________________________________________________________
# Dense4_block9_bn1 (BatchNormali (None, 14, 14, 512)  2048        Dense4_block8[0][0]
# __________________________________________________________________________________________________
# Dense4_block9_relu1 (Activation (None, 14, 14, 512)  0           Dense4_block9_bn1[0][0]
# __________________________________________________________________________________________________
# Dense4_block9_conv1 (Conv2D)    (None, 14, 14, 128)  65536       Dense4_block9_relu1[0][0]
# __________________________________________________________________________________________________
# Dense4_block9_bn2 (BatchNormali (None, 14, 14, 128)  512         Dense4_block9_conv1[0][0]
# ...
#                                                                  Dense5_block8_conv2[0][0]
# __________________________________________________________________________________________________
# Dense5_block9_bn1 (BatchNormali (None, 7, 7, 768)    3072        Dense5_block8[0][0]
# __________________________________________________________________________________________________
# Dense5_block9_relu1 (Activation (None, 7, 7, 768)    0           Dense5_block9_bn1[0][0]
# __________________________________________________________________________________________________
# Dense5_block9_conv1 (Conv2D)    (None, 7, 7, 128)    98304       Dense5_block9_relu1[0][0]
# __________________________________________________________________________________________________
# Dense5_block9_bn2 (BatchNormali (None, 7, 7, 128)    512         Dense5_block9_conv1[0][0]
# __________________________________________________________________________________________________
# Dense5_block9_relu2 (Activation (None, 7, 7, 128)    0           Dense5_block9_bn2[0][0]
# __________________________________________________________________________________________________
# Dense5_block9_zeropadding2 (Zer (None, 9, 9, 128)    0           Dense5_block9_relu2[0][0]
# __________________________________________________________________________________________________
# Dense5_block9_conv2 (Conv2D)    (None, 7, 7, 32)     36864       Dense5_block9_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense5_block9 (Concatenate)     (None, 7, 7, 800)    0           Dense5_block8[0][0]
#                                                                  Dense5_block9_conv2[0][0]
# __________________________________________________________________________________________________
# Dense5_block10_bn1 (BatchNormal (None, 7, 7, 800)    3200        Dense5_block9[0][0]
# __________________________________________________________________________________________________
# Dense5_block10_relu1 (Activatio (None, 7, 7, 800)    0           Dense5_block10_bn1[0][0]
# __________________________________________________________________________________________________
# Dense5_block10_conv1 (Conv2D)   (None, 7, 7, 128)    102400      Dense5_block10_relu1[0][0]
# __________________________________________________________________________________________________
# Dense5_block10_bn2 (BatchNormal (None, 7, 7, 128)    512         Dense5_block10_conv1[0][0]
# __________________________________________________________________________________________________
# Dense5_block10_relu2 (Activatio (None, 7, 7, 128)    0           Dense5_block10_bn2[0][0]
# __________________________________________________________________________________________________
# Dense5_block10_zeropadding2 (Ze (None, 9, 9, 128)    0           Dense5_block10_relu2[0][0]
# __________________________________________________________________________________________________
# Dense5_block10_conv2 (Conv2D)   (None, 7, 7, 32)     36864       Dense5_block10_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense5_block10 (Concatenate)    (None, 7, 7, 832)    0           Dense5_block9[0][0]
#                                                                  Dense5_block10_conv2[0][0]
# __________________________________________________________________________________________________
# Dense5_block11_bn1 (BatchNormal (None, 7, 7, 832)    3328        Dense5_block10[0][0]
# __________________________________________________________________________________________________
# Dense5_block11_relu1 (Activatio (None, 7, 7, 832)    0           Dense5_block11_bn1[0][0]
# __________________________________________________________________________________________________
# Dense5_block11_conv1 (Conv2D)   (None, 7, 7, 128)    106496      Dense5_block11_relu1[0][0]
# __________________________________________________________________________________________________
# Dense5_block11_bn2 (BatchNormal (None, 7, 7, 128)    512         Dense5_block11_conv1[0][0]
# __________________________________________________________________________________________________
# Dense5_block11_relu2 (Activatio (None, 7, 7, 128)    0           Dense5_block11_bn2[0][0]
# __________________________________________________________________________________________________
# Dense5_block11_zeropadding2 (Ze (None, 9, 9, 128)    0           Dense5_block11_relu2[0][0]
# __________________________________________________________________________________________________
# Dense5_block11_conv2 (Conv2D)   (None, 7, 7, 32)     36864       Dense5_block11_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense5_block11 (Concatenate)    (None, 7, 7, 864)    0           Dense5_block10[0][0]
#                                                                  Dense5_block11_conv2[0][0]
# __________________________________________________________________________________________________
# Dense5_block12_bn1 (BatchNormal (None, 7, 7, 864)    3456        Dense5_block11[0][0]
# __________________________________________________________________________________________________
# Dense5_block12_relu1 (Activatio (None, 7, 7, 864)    0           Dense5_block12_bn1[0][0]
# __________________________________________________________________________________________________
# Dense5_block12_conv1 (Conv2D)   (None, 7, 7, 128)    110592      Dense5_block12_relu1[0][0]
# __________________________________________________________________________________________________
# Dense5_block12_bn2 (BatchNormal (None, 7, 7, 128)    512         Dense5_block12_conv1[0][0]
# __________________________________________________________________________________________________
# Dense5_block12_relu2 (Activatio (None, 7, 7, 128)    0           Dense5_block12_bn2[0][0]
# __________________________________________________________________________________________________
# Dense5_block12_zeropadding2 (Ze (None, 9, 9, 128)    0           Dense5_block12_relu2[0][0]
# __________________________________________________________________________________________________
# Dense5_block12_conv2 (Conv2D)   (None, 7, 7, 32)     36864       Dense5_block12_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense5_block12 (Concatenate)    (None, 7, 7, 896)    0           Dense5_block11[0][0]
#                                                                  Dense5_block12_conv2[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_bn1 (BatchNormal (None, 7, 7, 896)    3584        Dense5_block12[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_relu1 (Activatio (None, 7, 7, 896)    0           Dense5_block13_bn1[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_conv1 (Conv2D)   (None, 7, 7, 128)    114688      Dense5_block13_relu1[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_bn2 (BatchNormal (None, 7, 7, 128)    512         Dense5_block13_conv1[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_relu2 (Activatio (None, 7, 7, 128)    0           Dense5_block13_bn2[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_zeropadding2 (Ze (None, 9, 9, 128)    0           Dense5_block13_relu2[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_conv2 (Conv2D)   (None, 7, 7, 32)     36864       Dense5_block13_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense5_block13 (Concatenate)    (None, 7, 7, 928)    0           Dense5_block12[0][0]
#                                                                  Dense5_block13_conv2[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_bn1 (BatchNormal (None, 7, 7, 928)    3712        Dense5_block13[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_relu1 (Activatio (None, 7, 7, 928)    0           Dense5_block14_bn1[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_conv1 (Conv2D)   (None, 7, 7, 128)    118784      Dense5_block14_relu1[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_bn2 (BatchNormal (None, 7, 7, 128)    512         Dense5_block14_conv1[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_relu2 (Activatio (None, 7, 7, 128)    0           Dense5_block14_bn2[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_zeropadding2 (Ze (None, 9, 9, 128)    0           Dense5_block14_relu2[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_conv2 (Conv2D)   (None, 7, 7, 32)     36864       Dense5_block14_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense5_block14 (Concatenate)    (None, 7, 7, 960)    0           Dense5_block13[0][0]
#                                                                  Dense5_block14_conv2[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_bn1 (BatchNormal (None, 7, 7, 960)    3840        Dense5_block14[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_relu1 (Activatio (None, 7, 7, 960)    0           Dense5_block15_bn1[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_conv1 (Conv2D)   (None, 7, 7, 128)    122880      Dense5_block15_relu1[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_bn2 (BatchNormal (None, 7, 7, 128)    512         Dense5_block15_conv1[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_relu2 (Activatio (None, 7, 7, 128)    0           Dense5_block15_bn2[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_zeropadding2 (Ze (None, 9, 9, 128)    0           Dense5_block15_relu2[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_conv2 (Conv2D)   (None, 7, 7, 32)     36864       Dense5_block15_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense5_block15 (Concatenate)    (None, 7, 7, 992)    0           Dense5_block14[0][0]
#                                                                  Dense5_block15_conv2[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_bn1 (BatchNormal (None, 7, 7, 992)    3968        Dense5_block15[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_relu1 (Activatio (None, 7, 7, 992)    0           Dense5_block16_bn1[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_conv1 (Conv2D)   (None, 7, 7, 128)    126976      Dense5_block16_relu1[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_bn2 (BatchNormal (None, 7, 7, 128)    512         Dense5_block16_conv1[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_relu2 (Activatio (None, 7, 7, 128)    0           Dense5_block16_bn2[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_zeropadding2 (Ze (None, 9, 9, 128)    0           Dense5_block16_relu2[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_conv2 (Conv2D)   (None, 7, 7, 32)     36864       Dense5_block16_zeropadding2[0][0]
# __________________________________________________________________________________________________
# Dense5_block16 (Concatenate)    (None, 7, 7, 1024)   0           Dense5_block15[0][0]
#                                                                  Dense5_block16_conv2[0][0]
# __________________________________________________________________________________________________
# final_conv_bn (BatchNormalizati (None, 7, 7, 1024)   4096        Dense5_block16[0][0]
# __________________________________________________________________________________________________
# final_act (Activation)          (None, 7, 7, 1024)   0           final_conv_bn[0][0]
# __________________________________________________________________________________________________
# final_pooling (GlobalAveragePoo (None, 1024)         0           final_act[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          524800      final_pooling[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            1026        dropout[0][0]
# ==================================================================================================
# Total params: 7,563,330
# Trainable params: 7,479,682
# Non-trainable params: 83,648
# __________________________________________________________________________________________________
# 2022-12-17 14:03:27.124491: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-12-17 14:03:27.124529: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-12-17 14:03:27.124582: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1614] Profiler found 1 GPUs
# 2022-12-17 14:03:27.125020: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /root/miniconda3/lib/python3.8/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-12-17 14:03:27.310566: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-12-17 14:03:27.310896: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed

# %%
reduce_LR = ReduceLROnPlateau(monitor="val_loss", 
                             factor = 0.5, 
                             patience = 2, 
                             min_delta=0.001, 
                             mode = "auto", 
                            verbose = 1)

# %%
history = model.fit(X_train, Y_train,
                  validation_split =0.1,
                  epochs =100, 
                  verbose =1, 
                  batch_size = 32, 
                  callbacks = [tensorboard, checkpoint, reduce_LR])
# Out:
# 2022-12-17 14:03:32.430231: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 8323596288 exceeds 10% of free system memory.
# 2022-12-17 14:03:41.982924: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 8323596288 exceeds 10% of free system memory.
# 2022-12-17 14:03:52.362279: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-12-17 14:04:04.430712: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8400
# 2022-12-17 14:04:06.875318: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
#   1/432 [..............................] - ETA: 1:51:50 - loss: 0.8098 - accuracy: 0.5000
# 2022-12-17 14:04:08.329872: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-12-17 14:04:08.329907: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
#   2/432 [..............................] - ETA: 13:04 - loss: 0.8612 - accuracy: 0.5312
# 2022-12-17 14:04:09.791153: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-12-17 14:04:09.792054: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed
# 2022-12-17 14:04:09.856809: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:673]  GpuTracer has collected 2909 callback api events and 2921 activity events.
# 2022-12-17 14:04:09.934025: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-12-17 14:04:10.017469: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: AD-CN-Freeze-1/train/plugins/profile/2022_12_17_14_04_09
#
# 2022-12-17 14:04:10.093742: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to AD-CN-Freeze-1/train/plugins/profile/2022_12_17_14_04_09/autodl-container-a33911ac3c-246d218f.trace.json.gz
# 2022-12-17 14:04:10.212585: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: AD-CN-Freeze-1/train/plugins/profile/2022_12_17_14_04_09
#   3/432 [..............................] - ETA: 8:32 - loss: 0.8329 - accuracy: 0.5417
# 2022-12-17 14:04:10.222028: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to AD-CN-Freeze-1/train/plugins/profile/2022_12_17_14_04_09/autodl-container-a33911ac3c-246d218f.memory_profile.json.gz
# 2022-12-17 14:04:10.226332: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: AD-CN-Freeze-1/train/plugins/profile/2022_12_17_14_04_09
# Dumped tool data for xplane.pb to AD-CN-Freeze-1/train/plugins/profile/2022_12_17_14_04_09/autodl-container-a33911ac3c-246d218f.xplane.pb
# Dumped tool data for overview_page.pb to AD-CN-Freeze-1/train/plugins/profile/2022_12_17_14_04_09/autodl-container-a33911ac3c-246d218f.overview_page.pb
# Dumped tool data for input_pipeline.pb to AD-CN-Freeze-1/train/plugins/profile/2022_12_17_14_04_09/autodl-container-a33911ac3c-246d218f.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to AD-CN-Freeze-1/train/plugins/profile/2022_12_17_14_04_09/autodl-container-a33911ac3c-246d218f.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to AD-CN-Freeze-1/train/plugins/profile/2022_12_17_14_04_09/autodl-container-a33911ac3c-246d218f.kernel_stats.pb
# 432/432 [==============================] - 71s 128ms/step - loss: 0.5729 - accuracy: 0.7115 - val_loss: 0.8762 - val_accuracy: 0.5104
#
# Epoch 00001: val_accuracy improved from -inf to 0.51042, saving model to AD-CN-Freeze-1.h5
# Epoch 2/100
# 432/432 [==============================] - 51s 117ms/step - loss: 0.5003 - accuracy: 0.7659 - val_loss: 1.2788 - val_accuracy: 0.5072
#
# Epoch 00002: val_accuracy did not improve from 0.51042
# Epoch 3/100
# 432/432 [==============================] - 53s 122ms/step - loss: 0.4512 - accuracy: 0.7988 - val_loss: 0.4424 - val_accuracy: 0.7871
#
# Epoch 00003: val_accuracy improved from 0.51042 to 0.78711, saving model to AD-CN-Freeze-1.h5
# Epoch 4/100
# 432/432 [==============================] - 54s 124ms/step - loss: 0.3919 - accuracy: 0.8324 - val_loss: 0.4512 - val_accuracy: 0.8053
#
# Epoch 00004: val_accuracy improved from 0.78711 to 0.80534, saving model to AD-CN-Freeze-1.h5
# Epoch 5/100
# 432/432 [==============================] - 53s 123ms/step - loss: 0.3161 - accuracy: 0.8704 - val_loss: 2.7200 - val_accuracy: 0.5247
#
# Epoch 00005: val_accuracy did not improve from 0.80534
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 6/100
# 432/432 [==============================] - 51s 119ms/step - loss: 0.1760 - accuracy: 0.9336 - val_loss: 0.4506 - val_accuracy: 0.8092
#
# Epoch 00006: val_accuracy improved from 0.80534 to 0.80924, saving model to AD-CN-Freeze-1.h5
# Epoch 7/100
# 432/432 [==============================] - 53s 122ms/step - loss: 0.1167 - accuracy: 0.9575 - val_loss: 1.5817 - val_accuracy: 0.6393
#
# Epoch 00007: val_accuracy did not improve from 0.80924
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 8/100
# 432/432 [==============================] - 51s 117ms/step - loss: 0.0528 - accuracy: 0.9836 - val_loss: 0.2659 - val_accuracy: 0.9062
#
# Epoch 00008: val_accuracy improved from 0.80924 to 0.90625, saving model to AD-CN-Freeze-1.h5
# Epoch 9/100
# 432/432 [==============================] - 51s 117ms/step - loss: 0.0298 - accuracy: 0.9899 - val_loss: 0.9361 - val_accuracy: 0.7858
#
# Epoch 00009: val_accuracy did not improve from 0.90625
# Epoch 10/100
# 432/432 [==============================] - 51s 119ms/step - loss: 0.0223 - accuracy: 0.9931 - val_loss: 0.1422 - val_accuracy: 0.9609
#
# Epoch 00010: val_accuracy improved from 0.90625 to 0.96094, saving model to AD-CN-Freeze-1.h5
# Epoch 11/100
# 432/432 [==============================] - 52s 120ms/step - loss: 0.0265 - accuracy: 0.9912 - val_loss: 1.0514 - val_accuracy: 0.8040
#
# Epoch 00011: val_accuracy did not improve from 0.96094
# Epoch 12/100
# 432/432 [==============================] - 53s 122ms/step - loss: 0.0211 - accuracy: 0.9927 - val_loss: 0.4003 - val_accuracy: 0.8965
#
# Epoch 00012: val_accuracy did not improve from 0.96094
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 13/100
# 432/432 [==============================] - 51s 117ms/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.1459 - val_accuracy: 0.9668
#
# Epoch 00013: val_accuracy improved from 0.96094 to 0.96680, saving model to AD-CN-Freeze-1.h5
# Epoch 14/100
# 432/432 [==============================] - 50s 117ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.2531 - val_accuracy: 0.9479
#
# Epoch 00014: val_accuracy did not improve from 0.96680
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 15/100
# 432/432 [==============================] - 52s 120ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.1099 - val_accuracy: 0.9753
#
# Epoch 00015: val_accuracy improved from 0.96680 to 0.97526, saving model to AD-CN-Freeze-1.h5
# Epoch 16/100
# 432/432 [==============================] - 50s 116ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.1203 - val_accuracy: 0.9727
#
# Epoch 00016: val_accuracy did not improve from 0.97526
# Epoch 17/100
# 432/432 [==============================] - 51s 119ms/step - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.1231 - val_accuracy: 0.9720
#
# Epoch 00017: val_accuracy did not improve from 0.97526
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 18/100
# 432/432 [==============================] - 53s 123ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.1001 - val_accuracy: 0.9766
#
# Epoch 00018: val_accuracy improved from 0.97526 to 0.97656, saving model to AD-CN-Freeze-1.h5
# Epoch 19/100
# 432/432 [==============================] - 50s 116ms/step - loss: 8.8112e-04 - accuracy: 0.9999 - val_loss: 0.0946 - val_accuracy: 0.9772
#
# Epoch 00019: val_accuracy improved from 0.97656 to 0.97721, saving model to AD-CN-Freeze-1.h5
# Epoch 20/100
# 432/432 [==============================] - 50s 116ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.1000 - val_accuracy: 0.9785
#
# Epoch 00020: val_accuracy improved from 0.97721 to 0.97852, saving model to AD-CN-Freeze-1.h5
# Epoch 21/100
# 432/432 [==============================] - 51s 119ms/step - loss: 7.6954e-04 - accuracy: 0.9999 - val_loss: 0.1026 - val_accuracy: 0.9798
#
# Epoch 00021: val_accuracy improved from 0.97852 to 0.97982, saving model to AD-CN-Freeze-1.h5
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 22/100
# 432/432 [==============================] - 50s 115ms/step - loss: 9.6162e-04 - accuracy: 0.9997 - val_loss: 0.0994 - val_accuracy: 0.9792
#
# Epoch 00022: val_accuracy did not improve from 0.97982
# Epoch 23/100
# 432/432 [==============================] - 50s 117ms/step - loss: 5.7576e-04 - accuracy: 0.9999 - val_loss: 0.1004 - val_accuracy: 0.9805
#
# Epoch 00023: val_accuracy improved from 0.97982 to 0.98047, saving model to AD-CN-Freeze-1.h5
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 24/100
# 432/432 [==============================] - 51s 118ms/step - loss: 5.3101e-04 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9798
#
# Epoch 00024: val_accuracy did not improve from 0.98047
# Epoch 25/100
# 432/432 [==============================] - 50s 115ms/step - loss: 7.8889e-04 - accuracy: 0.9998 - val_loss: 0.1037 - val_accuracy: 0.9798
#
# Epoch 00025: val_accuracy did not improve from 0.98047
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 26/100
# 432/432 [==============================] - 52s 120ms/step - loss: 4.4341e-04 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9798
#
# Epoch 00026: val_accuracy did not improve from 0.98047
# Epoch 27/100
# 432/432 [==============================] - 51s 118ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.1035 - val_accuracy: 0.9798
#
# Epoch 00027: val_accuracy did not improve from 0.98047
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 28/100
# 432/432 [==============================] - 50s 117ms/step - loss: 5.3724e-04 - accuracy: 0.9999 - val_loss: 0.1043 - val_accuracy: 0.9798
#
# Epoch 00028: val_accuracy did not improve from 0.98047
# Epoch 29/100
# 432/432 [==============================] - 53s 122ms/step - loss: 4.8426e-04 - accuracy: 0.9999 - val_loss: 0.1037 - val_accuracy: 0.9798
#
# Epoch 00029: val_accuracy did not improve from 0.98047
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 30/100
# 432/432 [==============================] - 50s 116ms/step - loss: 9.4078e-04 - accuracy: 0.9999 - val_loss: 0.1045 - val_accuracy: 0.9798
#
# Epoch 00030: val_accuracy did not improve from 0.98047
# Epoch 31/100
# 432/432 [==============================] - 49s 114ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.1040 - val_accuracy: 0.9798
#
# Epoch 00031: val_accuracy did not improve from 0.98047
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 32/100
# 432/432 [==============================] - 52s 121ms/step - loss: 9.2397e-04 - accuracy: 0.9997 - val_loss: 0.1039 - val_accuracy: 0.9798
#
# Epoch 00032: val_accuracy did not improve from 0.98047
# Epoch 33/100
# 432/432 [==============================] - 50s 115ms/step - loss: 8.5071e-04 - accuracy: 0.9999 - val_loss: 0.1043 - val_accuracy: 0.9798
#
# Epoch 00033: val_accuracy did not improve from 0.98047
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 34/100
# 432/432 [==============================] - 50s 115ms/step - loss: 6.9476e-04 - accuracy: 0.9999 - val_loss: 0.1039 - val_accuracy: 0.9798
#
# Epoch 00034: val_accuracy did not improve from 0.98047
# Epoch 35/100
# 432/432 [==============================] - 50s 116ms/step - loss: 5.6081e-04 - accuracy: 0.9999 - val_loss: 0.1038 - val_accuracy: 0.9798
#
# Epoch 00035: val_accuracy did not improve from 0.98047
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 36/100
# 432/432 [==============================] - 49s 115ms/step - loss: 7.8066e-04 - accuracy: 0.9997 - val_loss: 0.1032 - val_accuracy: 0.9798
#
# Epoch 00036: val_accuracy did not improve from 0.98047
# Epoch 37/100
# 432/432 [==============================] - 50s 116ms/step - loss: 7.3015e-04 - accuracy: 0.9998 - val_loss: 0.1033 - val_accuracy: 0.9798
#
# Epoch 00037: val_accuracy did not improve from 0.98047
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 38/100
# 432/432 [==============================] - 50s 115ms/step - loss: 9.3128e-04 - accuracy: 0.9998 - val_loss: 0.1040 - val_accuracy: 0.9798
#
# Epoch 00038: val_accuracy did not improve from 0.98047
# Epoch 39/100
# 432/432 [==============================] - 50s 115ms/step - loss: 8.9600e-04 - accuracy: 0.9999 - val_loss: 0.1034 - val_accuracy: 0.9798
#
# Epoch 00039: val_accuracy did not improve from 0.98047
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 40/100
# 432/432 [==============================] - 51s 118ms/step - loss: 3.8818e-04 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 0.9798
#
# Epoch 00040: val_accuracy did not improve from 0.98047
# Epoch 41/100
# 432/432 [==============================] - 51s 119ms/step - loss: 7.1277e-04 - accuracy: 0.9999 - val_loss: 0.1041 - val_accuracy: 0.9798
#
# Epoch 00041: val_accuracy did not improve from 0.98047
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 42/100
# 432/432 [==============================] - 53s 122ms/step - loss: 4.9759e-04 - accuracy: 0.9999 - val_loss: 0.1039 - val_accuracy: 0.9798
#
# Epoch 00042: val_accuracy did not improve from 0.98047
# Epoch 43/100
# 432/432 [==============================] - 52s 121ms/step - loss: 4.3296e-04 - accuracy: 0.9999 - val_loss: 0.1038 - val_accuracy: 0.9798
#
# Epoch 00043: val_accuracy did not improve from 0.98047
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 44/100
# 432/432 [==============================] - 49s 114ms/step - loss: 3.4717e-04 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 0.9798
#
# Epoch 00044: val_accuracy did not improve from 0.98047
# Epoch 45/100
# 432/432 [==============================] - 52s 121ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1035 - val_accuracy: 0.9798
#
# Epoch 00045: val_accuracy did not improve from 0.98047
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 46/100
# 432/432 [==============================] - 50s 117ms/step - loss: 3.7400e-04 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9798
#
# Epoch 00046: val_accuracy did not improve from 0.98047
# Epoch 47/100
# 432/432 [==============================] - 51s 118ms/step - loss: 8.3723e-04 - accuracy: 0.9999 - val_loss: 0.1034 - val_accuracy: 0.9798
#
# Epoch 00047: val_accuracy did not improve from 0.98047
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# Epoch 48/100
# 432/432 [==============================] - 50s 117ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.1028 - val_accuracy: 0.9798
#
# Epoch 00048: val_accuracy did not improve from 0.98047
# Epoch 49/100
# 432/432 [==============================] - 50s 117ms/step - loss: 5.9775e-04 - accuracy: 0.9999 - val_loss: 0.1043 - val_accuracy: 0.9798
#
# Epoch 00049: val_accuracy did not improve from 0.98047
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# Epoch 50/100
# 432/432 [==============================] - 52s 121ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1039 - val_accuracy: 0.9798
#
# Epoch 00050: val_accuracy did not improve from 0.98047
# Epoch 51/100
# 432/432 [==============================] - 52s 120ms/step - loss: 8.2327e-04 - accuracy: 0.9998 - val_loss: 0.1034 - val_accuracy: 0.9798
#
# Epoch 00051: val_accuracy did not improve from 0.98047
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 4.768371808516747e-10.
# Epoch 52/100
# 432/432 [==============================] - 56s 130ms/step - loss: 5.2320e-04 - accuracy: 0.9998 - val_loss: 0.1028 - val_accuracy: 0.9798
#
# Epoch 00052: val_accuracy did not improve from 0.98047
# Epoch 53/100
# 432/432 [==============================] - 57s 132ms/step - loss: 4.5962e-04 - accuracy: 0.9999 - val_loss: 0.1036 - val_accuracy: 0.9798
#
# Epoch 00053: val_accuracy did not improve from 0.98047
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 2.3841859042583735e-10.
# Epoch 54/100
# 432/432 [==============================] - 56s 129ms/step - loss: 4.2518e-04 - accuracy: 0.9999 - val_loss: 0.1038 - val_accuracy: 0.9798
#
# Epoch 00054: val_accuracy did not improve from 0.98047
# Epoch 55/100
# 432/432 [==============================] - 56s 129ms/step - loss: 6.1558e-04 - accuracy: 0.9999 - val_loss: 0.1033 - val_accuracy: 0.9798
#
# Epoch 00055: val_accuracy did not improve from 0.98047
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 1.1920929521291868e-10.
# Epoch 56/100
# 432/432 [==============================] - 56s 129ms/step - loss: 6.8483e-04 - accuracy: 0.9998 - val_loss: 0.1032 - val_accuracy: 0.9798
#
# Epoch 00056: val_accuracy did not improve from 0.98047
# Epoch 57/100
# 432/432 [==============================] - 54s 124ms/step - loss: 3.8737e-04 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9798
#
# Epoch 00057: val_accuracy did not improve from 0.98047
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 5.960464760645934e-11.
# Epoch 58/100
# 432/432 [==============================] - 53s 122ms/step - loss: 8.3381e-04 - accuracy: 0.9997 - val_loss: 0.1038 - val_accuracy: 0.9798
#
# Epoch 00058: val_accuracy did not improve from 0.98047
# Epoch 59/100
# 432/432 [==============================] - 55s 128ms/step - loss: 3.8638e-04 - accuracy: 1.0000 - val_loss: 0.1039 - val_accuracy: 0.9798
#
# Epoch 00059: val_accuracy did not improve from 0.98047
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 2.980232380322967e-11.
# Epoch 60/100
# 432/432 [==============================] - 55s 128ms/step - loss: 5.1441e-04 - accuracy: 0.9999 - val_loss: 0.1031 - val_accuracy: 0.9798
#
# Epoch 00060: val_accuracy did not improve from 0.98047
# Epoch 61/100
# 432/432 [==============================] - 55s 127ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.1031 - val_accuracy: 0.9798
#
# Epoch 00061: val_accuracy did not improve from 0.98047
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 1.4901161901614834e-11.
# Epoch 62/100
# 432/432 [==============================] - 55s 128ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1035 - val_accuracy: 0.9798
#
# Epoch 00062: val_accuracy did not improve from 0.98047
# Epoch 63/100
# 432/432 [==============================] - 54s 125ms/step - loss: 4.8924e-04 - accuracy: 0.9999 - val_loss: 0.1030 - val_accuracy: 0.9798
#
# Epoch 00063: val_accuracy did not improve from 0.98047
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 7.450580950807417e-12.
# Epoch 64/100
# 432/432 [==============================] - 56s 129ms/step - loss: 7.6627e-04 - accuracy: 0.9997 - val_loss: 0.1034 - val_accuracy: 0.9798
#
# Epoch 00064: val_accuracy did not improve from 0.98047
# Epoch 65/100
# 432/432 [==============================] - 57s 132ms/step - loss: 7.7930e-04 - accuracy: 0.9998 - val_loss: 0.1040 - val_accuracy: 0.9798
#
# Epoch 00065: val_accuracy did not improve from 0.98047
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 3.725290475403709e-12.
# Epoch 66/100
# 432/432 [==============================] - 55s 126ms/step - loss: 3.4105e-04 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9798
#
# Epoch 00066: val_accuracy did not improve from 0.98047
# Epoch 67/100
# 432/432 [==============================] - 54s 125ms/step - loss: 3.4726e-04 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 0.9798
#
# Epoch 00067: val_accuracy did not improve from 0.98047
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 1.8626452377018543e-12.
# Epoch 68/100
# 432/432 [==============================] - 54s 126ms/step - loss: 7.1962e-04 - accuracy: 0.9998 - val_loss: 0.1035 - val_accuracy: 0.9798
#
# Epoch 00068: val_accuracy did not improve from 0.98047
# Epoch 69/100
# 432/432 [==============================] - 53s 123ms/step - loss: 3.8803e-04 - accuracy: 0.9999 - val_loss: 0.1039 - val_accuracy: 0.9798
#
# Epoch 00069: val_accuracy did not improve from 0.98047
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 9.313226188509272e-13.
# Epoch 70/100
# 432/432 [==============================] - 49s 113ms/step - loss: 5.6811e-04 - accuracy: 0.9999 - val_loss: 0.1036 - val_accuracy: 0.9798
#
# Epoch 00070: val_accuracy did not improve from 0.98047
# Epoch 71/100
# 432/432 [==============================] - 51s 118ms/step - loss: 7.8534e-04 - accuracy: 0.9999 - val_loss: 0.1038 - val_accuracy: 0.9798
#
# Epoch 00071: val_accuracy did not improve from 0.98047
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 4.656613094254636e-13.
# Epoch 72/100
# 432/432 [==============================] - 50s 115ms/step - loss: 2.9609e-04 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9792
#
# Epoch 00072: val_accuracy did not improve from 0.98047
# Epoch 73/100
# 432/432 [==============================] - 49s 113ms/step - loss: 8.4242e-04 - accuracy: 0.9997 - val_loss: 0.1040 - val_accuracy: 0.9798
#
# Epoch 00073: val_accuracy did not improve from 0.98047
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 2.328306547127318e-13.
# Epoch 74/100
# 432/432 [==============================] - 50s 116ms/step - loss: 6.6299e-04 - accuracy: 0.9999 - val_loss: 0.1035 - val_accuracy: 0.9798
#
# Epoch 00074: val_accuracy did not improve from 0.98047
# Epoch 75/100
# 432/432 [==============================] - 52s 120ms/step - loss: 6.9799e-04 - accuracy: 0.9999 - val_loss: 0.1043 - val_accuracy: 0.9798
#
# Epoch 00075: val_accuracy did not improve from 0.98047
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 1.164153273563659e-13.
# Epoch 76/100
# 432/432 [==============================] - 51s 118ms/step - loss: 3.5541e-04 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9798
#
# Epoch 00076: val_accuracy did not improve from 0.98047
# Epoch 77/100
# 432/432 [==============================] - 51s 117ms/step - loss: 7.8091e-04 - accuracy: 0.9999 - val_loss: 0.1027 - val_accuracy: 0.9798
#
# Epoch 00077: val_accuracy did not improve from 0.98047
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 5.820766367818295e-14.
# Epoch 78/100
# 432/432 [==============================] - 54s 124ms/step - loss: 4.6181e-04 - accuracy: 0.9999 - val_loss: 0.1035 - val_accuracy: 0.9798
#
# Epoch 00078: val_accuracy did not improve from 0.98047
# Epoch 79/100
# 432/432 [==============================] - 50s 115ms/step - loss: 6.6740e-04 - accuracy: 0.9999 - val_loss: 0.1034 - val_accuracy: 0.9798
#
# Epoch 00079: val_accuracy did not improve from 0.98047
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 2.9103831839091474e-14.
# Epoch 80/100
# 432/432 [==============================] - 51s 118ms/step - loss: 5.8988e-04 - accuracy: 0.9999 - val_loss: 0.1036 - val_accuracy: 0.9798
#
# Epoch 00080: val_accuracy did not improve from 0.98047
# Epoch 81/100
# 432/432 [==============================] - 51s 119ms/step - loss: 7.8321e-04 - accuracy: 0.9999 - val_loss: 0.1031 - val_accuracy: 0.9798
#
# Epoch 00081: val_accuracy did not improve from 0.98047
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 1.4551915919545737e-14.
# Epoch 82/100
# 432/432 [==============================] - 51s 117ms/step - loss: 5.8821e-04 - accuracy: 0.9999 - val_loss: 0.1044 - val_accuracy: 0.9798
#
# Epoch 00082: val_accuracy did not improve from 0.98047
# Epoch 83/100
# 432/432 [==============================] - 49s 115ms/step - loss: 3.3740e-04 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 0.9798
#
# Epoch 00083: val_accuracy did not improve from 0.98047
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 7.275957959772868e-15.
# Epoch 84/100
# 432/432 [==============================] - 49s 114ms/step - loss: 6.1836e-04 - accuracy: 0.9999 - val_loss: 0.1035 - val_accuracy: 0.9798
#
# Epoch 00084: val_accuracy did not improve from 0.98047
# Epoch 85/100
# 432/432 [==============================] - 55s 128ms/step - loss: 5.1350e-04 - accuracy: 0.9999 - val_loss: 0.1032 - val_accuracy: 0.9798
#
# Epoch 00085: val_accuracy did not improve from 0.98047
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 3.637978979886434e-15.
# Epoch 86/100
# 432/432 [==============================] - 54s 124ms/step - loss: 5.2027e-04 - accuracy: 0.9999 - val_loss: 0.1032 - val_accuracy: 0.9798
#
# Epoch 00086: val_accuracy did not improve from 0.98047
# Epoch 87/100
# 432/432 [==============================] - 54s 125ms/step - loss: 4.0087e-04 - accuracy: 0.9999 - val_loss: 0.1037 - val_accuracy: 0.9798
#
# Epoch 00087: val_accuracy did not improve from 0.98047
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1.818989489943217e-15.
# Epoch 88/100
# 432/432 [==============================] - 51s 118ms/step - loss: 5.8338e-04 - accuracy: 0.9999 - val_loss: 0.1042 - val_accuracy: 0.9798
#
# Epoch 00088: val_accuracy did not improve from 0.98047
# Epoch 89/100
# 432/432 [==============================] - 50s 116ms/step - loss: 2.9506e-04 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9798
#
# Epoch 00089: val_accuracy did not improve from 0.98047
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 9.094947449716085e-16.
# Epoch 90/100
# 432/432 [==============================] - 50s 116ms/step - loss: 8.0282e-04 - accuracy: 0.9999 - val_loss: 0.1031 - val_accuracy: 0.9798
#
# Epoch 00090: val_accuracy did not improve from 0.98047
# Epoch 91/100
# 432/432 [==============================] - 49s 113ms/step - loss: 6.2758e-04 - accuracy: 0.9999 - val_loss: 0.1043 - val_accuracy: 0.9798
#
# Epoch 00091: val_accuracy did not improve from 0.98047
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 4.547473724858043e-16.
# Epoch 92/100
# 432/432 [==============================] - 49s 114ms/step - loss: 7.4316e-04 - accuracy: 0.9999 - val_loss: 0.1039 - val_accuracy: 0.9798
#
# Epoch 00092: val_accuracy did not improve from 0.98047
# Epoch 93/100
# 432/432 [==============================] - 49s 114ms/step - loss: 7.7929e-04 - accuracy: 0.9999 - val_loss: 0.1036 - val_accuracy: 0.9798
#
# Epoch 00093: val_accuracy did not improve from 0.98047
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 2.2737368624290214e-16.
# Epoch 94/100
# 432/432 [==============================] - 50s 115ms/step - loss: 7.8714e-04 - accuracy: 0.9998 - val_loss: 0.1032 - val_accuracy: 0.9798
#
# Epoch 00094: val_accuracy did not improve from 0.98047
# Epoch 95/100
# 432/432 [==============================] - 49s 114ms/step - loss: 3.6461e-04 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9798
#
# Epoch 00095: val_accuracy did not improve from 0.98047
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 1.1368684312145107e-16.
# Epoch 96/100
# 432/432 [==============================] - 50s 115ms/step - loss: 6.9274e-04 - accuracy: 0.9998 - val_loss: 0.1038 - val_accuracy: 0.9798
#
# Epoch 00096: val_accuracy did not improve from 0.98047
# Epoch 97/100
# 432/432 [==============================] - 50s 115ms/step - loss: 6.6858e-04 - accuracy: 0.9999 - val_loss: 0.1037 - val_accuracy: 0.9798
#
# Epoch 00097: val_accuracy did not improve from 0.98047
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 5.684342156072553e-17.
# Epoch 98/100
# 432/432 [==============================] - 49s 114ms/step - loss: 3.1230e-04 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9798
#
# Epoch 00098: val_accuracy did not improve from 0.98047
# Epoch 99/100
# 432/432 [==============================] - 49s 113ms/step - loss: 3.6680e-04 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9798
#
# Epoch 00099: val_accuracy did not improve from 0.98047
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 2.842171078036277e-17.
# Epoch 100/100
# 432/432 [==============================] - 49s 114ms/step - loss: 3.0627e-04 - accuracy: 0.9999 - val_loss: 0.1033 - val_accuracy: 0.9798
#
# Epoch 00100: val_accuracy did not improve from 0.98047

# %%
def accuracy_lr_loss_plot (history):
    fig = plt.figure(figsize=(15,10))
    
    plt.subplot(221)
    plt.plot(history.history["loss"], "bo--", label="loss")
    plt.plot(history.history["val_loss"], "ro--", label = "val_loss")
    plt.title("Training Data Loss")
    plt.xlabel("Number of epochs")
    plt.ylabel("loss")
    plt.grid()
    plt.legend()
    plt.tight_layout()
    
    plt.subplot(222)
    plt.plot(history.history["accuracy"], 'bo--', label="accuracy")
    plt.plot(history.history['val_accuracy'], 'ro--', label="val_accuracy")
    plt.title("Training Data Accuracy Measurements")
    plt.xlabel("Number of epochs")
    plt.ylabel("Accuracy")
    plt.grid()
    plt.legend()
    plt.tight_layout()
    
   
    
    plt.show()

# %%
accuracy_lr_loss_plot(history)

# %%
result= model.evaluate(X_test,Y_test,batch_size=32)
print("Accuracy is\n",result)

# dataFrame = pd.DataFrame({"loss":result[0], "accuracy":result[1]}, index=[0])

# dataFrame.to_csv("AD-CN-Classification.csv", index=False, mode="a")

# dataFrame.to_csv("AD-CN-Classification.csv", index=False, mode="a", header=False)
# Out:
# 120/120 [==============================] - 5s 33ms/step - loss: 0.1202 - accuracy: 0.9781
# Accuracy is
#  [0.12016195803880692, 0.9781249761581421]

# %% [markdown]
# ### 绘制混淆矩阵及特异-敏感性分析

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

labels = ["AD", "CN"]

y_pred = model.predict(X_test)
y_pred=np.argmax(y_pred, axis=1)
y_test_new = np.argmax(Y_test, axis=1)
target_names = labels

# %%
print(classification_report(y_test_new, y_pred,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#           AD       0.98      0.98      0.98      1891
#           CN       0.98      0.98      0.98      1949
#
#     accuracy                           0.98      3840
#    macro avg       0.98      0.98      0.98      3840
# weighted avg       0.98      0.98      0.98      3840

# %%
cm=confusion_matrix(y_test_new, y_pred)
display_c_m = ConfusionMatrixDisplay(cm, display_labels=labels)
fig, ax = plt.subplots(figsize=(25,10)) 
display_c_m.plot(cmap='mako',ax=ax,xticks_rotation=60)
plt.title("Confusion Metrics")
plt.show()

# %%
Sensitivity = cm[0][0] / (cm[0][0] + cm[0][1])
Specificity = cm[1][1] / (cm[1][0] + cm[1][1])
print("Sensitivity: " + str(Sensitivity))
print("Specificity: " + str(Specificity))
# Out:
# Sensitivity: 0.9756742464304601
# Specificity: 0.9805028219599795

# %%
# 在医学统计里，任何一个诊断指标，都有两个最基本的特征，即敏感性和特异性。
# 所谓敏感性，就是指其在诊断疾病的时候不漏诊的机会有多大，所谓特异性就是指该指标在诊断某疾病时，不误诊的机会有多大。
# 单独一个指标，如果提高其诊断的敏感性，必然降低其诊断的特异性，换句话说，减少漏诊必然增加误诊，反之亦然

# %%
from sklearn.metrics import precision_recall_fscore_support

res = []
for i in labels:
    prec, recall, _, _ = precision_recall_fscore_support(np.array(y_test_new)==1,
                                                         np.array(y_pred)==1,
                                                         pos_label=True, average=None)
    
    res.append([i, recall[0], recall[1]])

pd.DataFrame(res, columns = ["class", "sensitivity", "specificity"])
# Out:
#   class  sensitivity  specificity
# 0    AD     0.975674     0.980503
# 1    CN     0.975674     0.980503

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score
acc = accuracy_score(y_test_new, y_pred)
pre = precision_score(y_test_new, y_pred, average='macro') 
recall = recall_score(y_test_new, y_pred, average='macro')

print("acc: " + str(acc))
print("pre: " + str(pre))
print("recall: " + str(recall))
# Out:
# acc: 0.978125
# pre: 0.9781570358566862
# recall: 0.9780885341952198

# %% [markdown]
# ### 保存训练的历史记录，方便以后再次画图

# %%
# 保存训练的历史记录pickle.dump()
import pickle

history_filename = "AD-CN-Freeze-1.json"
with open(history_filename, "wb") as file_json:
    pickle.dump(history.history, file_json)

# %%
# 读取保存的训练历史记录
with open(history_filename, "rb") as file_json:
    history_file = pickle.load(file_json)

# %%
def accuracy_lr_loss_plot_file (history_file):
    fig = plt.figure(figsize=(15,10))
    
    plt.subplot(221)
    plt.plot(history_file["loss"], "bo--", label="loss")
    plt.plot(history_file["val_loss"], "ro--", label = "val_loss")
    plt.title("Training Data Loss")
    plt.xlabel("Number of epochs")
    plt.ylabel("loss")
    plt.grid()
    plt.legend()
    plt.tight_layout()
    
    plt.subplot(222)
    plt.plot(history_file["accuracy"], 'bo--', label="accuracy")
    plt.plot(history_file['val_accuracy'], 'ro--', label="val_accuracy")
    plt.title("Training Data Accuracy Measurements")
    plt.xlabel("Number of epochs")
    plt.ylabel("Accuracy")
    plt.grid()
    plt.legend()
    plt.tight_layout()
    
   
    
    plt.show()

# %%
accuracy_lr_loss_plot_file(history_file)
