# %% [markdown]
# ## 引包

# %%
import os
import cv2
import io
import glob
import random
import numpy as np
import pandas as pd
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint,ReduceLROnPlateau
from tensorflow import keras
from tensorflow.keras import layers, models, Sequential, backend
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization, Activation, GlobalAveragePooling2D
from tensorflow.keras.layers import Concatenate, Lambda, Input, ZeroPadding2D, AveragePooling2D
from keras.utils.np_utils import to_categorical

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix

import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
import ipywidgets as widgets
from IPython.display import clear_output,display

#调用GPU方法
config = tf.compat.v1.ConfigProto(gpu_options=tf.compat.v1.GPUOptions(allow_growth=True))
sess = tf.compat.v1.Session(config=config)
# 选择编号为0的GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"#我的笔记本只有一块GPU，编号是0，所以这里调用编号为0的GPU


SEED=6
tf.random.set_seed(SEED)
# Out:
# 2023-01-10 18:28:15.857435: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-10 18:28:16.554458: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22320 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:ce:00.0, compute capability: 8.6

# %% [markdown]
# ## 加载数据

# %%
x_train_savepath = '../../../autodl-tmp/X_train.npy'
y_train_savepath = '../../../autodl-tmp/Y_train.npy'
x_test_savepath = '../../../autodl-tmp/X_test.npy'
y_test_savepath = '../../../autodl-tmp/Y_test.npy'

def load_data():
    #如果数据集数组文件存在, 就直接载入
    if os.path.exists(x_train_savepath) and os.path.exists(y_train_savepath) and os.path.exists(
            x_test_savepath) and os.path.exists(y_test_savepath):
        X_train = np.load(x_train_savepath)
        Y_train = np.load(y_train_savepath)
        X_test = np.load(x_test_savepath)
        Y_test = np.load(y_test_savepath)
    return X_train, Y_train, X_test, Y_test


X_train, Y_train, X_test, Y_test = load_data()

# %%
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("Y_train:", Y_train.shape)
print("Y_test:", Y_test.shape)
# Out:
# X_train: (23040, 224, 224, 3)
# X_test: (5760, 224, 224, 3)
# Y_train: (23040, 3)
# Y_test: (5760, 3)

# %%
import re

def is_in(full_str, sub_str):
    if re.findall(sub_str, full_str):
        return True
    else:
        return False

# %% [markdown]
# ## 搭建模型DenseNet121

# %%
# 引入SeNet,增强通道注意力
def senet_block(inputs, ratio):
    shape = inputs.shape
    channel_out = shape[-1]
    # print(shape)
    # (2, 28, 28, 32) , [1,28,28,1], [1,28,28,1]
    squeeze = layers.GlobalAveragePooling2D()(inputs)
    # [2, 1, 1, 32]
    # print(squeeze.shape)
    # 第二层，全连接层
    # [2,32]
    # print(squeeze.shape)
    shape_result = layers.Flatten()(squeeze)
    # print(shape_result.shape)
    # [32,2]
    shape_result = layers.Dense(int(channel_out / ratio), activation='relu')(shape_result)
    # shape_result = layers.BatchNormalization()(shape_result)
    # [2,32]
    shape_result = layers.Dense(channel_out, activation='sigmoid')(shape_result)
    # shape_result = layers.BatchNormalization()(shape_result)

    # 第四层，点乘
    # print('heres2')
    excitation_output = tf.reshape(shape_result, [-1, 1, 1, channel_out])
    # print(excitation_output.shape)
    h_output = excitation_output * inputs
    return h_output



# Conv_Block：卷积单元 BN-RELU-CONV(1X1) —— BN-RELU-CONV(3X3) —— SeNet
def conv_block(x, nb_filter, dropout_rate=None, name=None, r=16):
    
    inter_channel = nb_filter*4

    # 1x1 convolution， 
    # epsilon 将小浮点数添加到方差以避免被零除
    # data_format="channels_first"，(batch_size, channels,height, width)则在BatchNormalization中设置axis=1，默认是channels_last，则设置axis=3
    x = BatchNormalization(epsilon=1.1e-5, axis=3, name=name+'_bn1')(x)
    x = Activation('relu', name=name+'_relu1')(x)
    x = Conv2D(inter_channel, 1, 1, name=name+'_conv1', use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    # 3x3 convolution
    x = BatchNormalization(epsilon=1.1e-5, axis=3, name=name+'_bn2')(x)
    x = Activation('relu', name=name+'_relu2')(x)
    x = ZeroPadding2D((1, 1), name=name+'_zeropadding2')(x)
    x = Conv2D(nb_filter, 3, 1, name=name+'_conv2', use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)
    
    # 加SE注意力机制
    # x = Squeeze_excitation_layer(r)(x)
    x= senet_block(x, r)
    return x


# Dense_Block 卷积组：由N个卷积单元组构成Dense Block
def dense_block(x, stage, nb_layers, nb_filter, growth_rate, dropout_rate=None, 
                grow_nb_filters=True, name =None, r = 16):

    concat_feat = x # store the last layer output

    for i in range(nb_layers):
        
        branch = i+1
        x =conv_block(concat_feat, growth_rate, dropout_rate, name=name+str(stage)+'_block'+str(branch), r=r) # 在参考的基础，修改的地方这里应该是相同的growth_rate=32
        concat_feat = Concatenate(axis=3, name=name+str(stage)+'_block'+str(branch))([concat_feat, x])

        
        if grow_nb_filters:
            nb_filter += growth_rate

    return concat_feat, nb_filter



# Transition_Block： 每个Dense block之间的传递block，主要用来降低特征层数
def transition_block (x,stage, nb_filter, compression=1.0, dropout_rate=None, name=None):

    x = BatchNormalization(epsilon=1.1e-5, axis=3, name=name+str(stage)+'_bn')(x)
    x = Activation('relu', name=name+str(stage)+'_relu')(x)
    
    x = Conv2D(int(nb_filter*compression), 1, 1, name=name+str(stage)+'_conv', use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)
    
    x = AveragePooling2D((2,2), strides=(2,2), name=name+str(stage)+'_pooling2d')(x)

    # x= senet_block(x, 16)
    return x



# Se-DenseNet: 121
def DenseNet(nb_dense_block=4, growth_rate=32, nb_filter=64, reduction=0.0, dropout_rate=0.0, weight_decay=1e-4, classes=1000, weights_path=None, r=16):

    compression = 1.0-reduction
    nb_filter=64
    nb_layers = [6, 12, 24, 16]  #For DenseNet-121
    
    img_input = Input(shape=(224,224,3))

    #initial convolution
    x = ZeroPadding2D((3, 3), name='conv1_zeropadding')(img_input)        # (3, 3)  s=1
    x = Conv2D(nb_filter, 7, 2, name='conv1', use_bias=False)(x)          # ====(7, 7)  s=2==== Conv2D
    x = BatchNormalization(epsilon=1.1e-5, axis=3, name='conv1_bn')(x)    
    x = Activation('relu', name='relu1')(x)
    x = ZeroPadding2D((1, 1), name='pool1_zeropadding')(x)                # (1, 1)  s=1
    x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1')(x)             # ====(3, 3 ) s=2==== MaxPooling

    #Dense block and Transition layer
    for block_id in range(nb_dense_block-1):
        stage = block_id+2 # start from 2

        x, nb_filter = dense_block(x, stage, nb_layers[block_id], nb_filter, growth_rate, 
        dropout_rate=dropout_rate, name='Dense', r=r)

        x = transition_block(x, stage, nb_filter, compression=compression, dropout_rate=dropout_rate, name='Trans')
        nb_filter *=compression
    
    final_stage = stage + 1
    x, nb_filter=dense_block(x, final_stage, nb_layers[-1], nb_filter, growth_rate, 
        dropout_rate=dropout_rate, name='Dense')

    # top layer
    x = BatchNormalization(name= 'final_conv_bn')(x)
    x = Activation('relu', name='final_act')(x)
    x = GlobalAveragePooling2D(name='final_pooling')(x)
    # x = Dense(classes, activation='softmax', name='fc')(x)

    model=models.Model(img_input, x, name='DenseNet_SE')

    return model


conv_base = DenseNet(reduction=.5)
path_weights = "../densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5"
conv_base.load_weights(path_weights, by_name=True, skip_mismatch=True)
conv_base.trainable = True

model=conv_base.output

model=tf.keras.layers.Dense(512,activation='relu')(model)
model=tf.keras.layers.Dropout(0.5)(model)
model=tf.keras.layers.Dense(3,activation="softmax")(model)
model=tf.keras.models.Model(inputs=conv_base.input,outputs=model)

model.compile(loss="categorical_crossentropy",optimizer="adam",metrics=["accuracy"])
model.summary()

tensorboard = TensorBoard(log_dir="AD-CN-MCI-SE-Denseblock-SE")
checkpoint = ModelCheckpoint("AD-CN-MCI-SE-Denseblock-SE.h5", 
                            monitor='val_accuracy', 
                            mode = "auto", 
                            verbose = 1,
                            save_best_only =True)
# Out:
# 2023-01-10 18:28:43.084742: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22320 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:ce:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_zeropadding (ZeroPadding2 (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9408        conv1_zeropadding[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_zeropadding (ZeroPadding2 (None, 114, 114, 64) 0           relu1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           pool1_zeropadding[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_bn1 (BatchNormali (None, 56, 56, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_relu1 (Activation (None, 56, 56, 64)   0           Dense2_block1_bn1[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_conv1 (Conv2D)    (None, 56, 56, 128)  8192        Dense2_block1_relu1[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_bn2 (BatchNormali (None, 56, 56, 128)  512         Dense2_block1_conv1[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_relu2 (Activation (None, 56, 56, 128)  0           Dense2_block1_bn2[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_zeropadding2 (Zer (None, 58, 58, 128)  0           Dense2_block1_relu2[0][0]
# __________________________________________________________________________________________________
# Dense2_block1_conv2 (Conv2D)    (None, 56, 56, 32)   36864       Dense2_block1_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 32)           0           Dense2_block1_conv2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 32)           0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            66          flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           96          dense[0][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None, 1, 1, 32)     0           dense_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 56, 56, 32)   0           tf.reshape[0][0]
#                                                                  Dense2_block1_conv2[0][0]
# __________________________________________________________________________________________________
# Dense2_block1 (Concatenate)     (None, 56, 56, 96)   0           pool1[0][0]
#                                                                  tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_bn1 (BatchNormali (None, 56, 56, 96)   384         Dense2_block1[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_relu1 (Activation (None, 56, 56, 96)   0           Dense2_block2_bn1[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_conv1 (Conv2D)    (None, 56, 56, 128)  12288       Dense2_block2_relu1[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_bn2 (BatchNormali (None, 56, 56, 128)  512         Dense2_block2_conv1[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_relu2 (Activation (None, 56, 56, 128)  0           Dense2_block2_bn2[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_zeropadding2 (Zer (None, 58, 58, 128)  0           Dense2_block2_relu2[0][0]
# __________________________________________________________________________________________________
# Dense2_block2_conv2 (Conv2D)    (None, 56, 56, 32)   36864       Dense2_block2_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 32)           0           Dense2_block2_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 32)           0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            66          flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           96          dense_2[0][0]
# __________________________________________________________________________________________________
# tf.reshape_1 (TFOpLambda)       (None, 1, 1, 32)     0           dense_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 56, 56, 32)   0           tf.reshape_1[0][0]
#                                                                  Dense2_block2_conv2[0][0]
# __________________________________________________________________________________________________
# Dense2_block2 (Concatenate)     (None, 56, 56, 128)  0           Dense2_block1[0][0]
#                                                                  tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_bn1 (BatchNormali (None, 56, 56, 128)  512         Dense2_block2[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_relu1 (Activation (None, 56, 56, 128)  0           Dense2_block3_bn1[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_conv1 (Conv2D)    (None, 56, 56, 128)  16384       Dense2_block3_relu1[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_bn2 (BatchNormali (None, 56, 56, 128)  512         Dense2_block3_conv1[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_relu2 (Activation (None, 56, 56, 128)  0           Dense2_block3_bn2[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_zeropadding2 (Zer (None, 58, 58, 128)  0           Dense2_block3_relu2[0][0]
# __________________________________________________________________________________________________
# Dense2_block3_conv2 (Conv2D)    (None, 56, 56, 32)   36864       Dense2_block3_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 32)           0           Dense2_block3_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 32)           0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2)            66          flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 32)           96          dense_4[0][0]
# __________________________________________________________________________________________________
# tf.reshape_2 (TFOpLambda)       (None, 1, 1, 32)     0           dense_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 56, 56, 32)   0           tf.reshape_2[0][0]
#                                                                  Dense2_block3_conv2[0][0]
# __________________________________________________________________________________________________
# Dense2_block3 (Concatenate)     (None, 56, 56, 160)  0           Dense2_block2[0][0]
#                                                                  tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_bn1 (BatchNormali (None, 56, 56, 160)  640         Dense2_block3[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_relu1 (Activation (None, 56, 56, 160)  0           Dense2_block4_bn1[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_conv1 (Conv2D)    (None, 56, 56, 128)  20480       Dense2_block4_relu1[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_bn2 (BatchNormali (None, 56, 56, 128)  512         Dense2_block4_conv1[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_relu2 (Activation (None, 56, 56, 128)  0           Dense2_block4_bn2[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_zeropadding2 (Zer (None, 58, 58, 128)  0           Dense2_block4_relu2[0][0]
# __________________________________________________________________________________________________
# Dense2_block4_conv2 (Conv2D)    (None, 56, 56, 32)   36864       Dense2_block4_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 32)           0           Dense2_block4_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 32)           0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 2)            66          flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 32)           96          dense_6[0][0]
# __________________________________________________________________________________________________
# tf.reshape_3 (TFOpLambda)       (None, 1, 1, 32)     0           dense_7[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 56, 56, 32)   0           tf.reshape_3[0][0]
#                                                                  Dense2_block4_conv2[0][0]
# __________________________________________________________________________________________________
# Dense2_block4 (Concatenate)     (None, 56, 56, 192)  0           Dense2_block3[0][0]
#                                                                  tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_bn1 (BatchNormali (None, 56, 56, 192)  768         Dense2_block4[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_relu1 (Activation (None, 56, 56, 192)  0           Dense2_block5_bn1[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_conv1 (Conv2D)    (None, 56, 56, 128)  24576       Dense2_block5_relu1[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_bn2 (BatchNormali (None, 56, 56, 128)  512         Dense2_block5_conv1[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_relu2 (Activation (None, 56, 56, 128)  0           Dense2_block5_bn2[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_zeropadding2 (Zer (None, 58, 58, 128)  0           Dense2_block5_relu2[0][0]
# __________________________________________________________________________________________________
# Dense2_block5_conv2 (Conv2D)    (None, 56, 56, 32)   36864       Dense2_block5_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 32)           0           Dense2_block5_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 32)           0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 2)            66          flatten_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 32)           96          dense_8[0][0]
# __________________________________________________________________________________________________
# tf.reshape_4 (TFOpLambda)       (None, 1, 1, 32)     0           dense_9[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 56, 56, 32)   0           tf.reshape_4[0][0]
#                                                                  Dense2_block5_conv2[0][0]
# __________________________________________________________________________________________________
# Dense2_block5 (Concatenate)     (None, 56, 56, 224)  0           Dense2_block4[0][0]
#                                                                  tf.math.multiply_4[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_bn1 (BatchNormali (None, 56, 56, 224)  896         Dense2_block5[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_relu1 (Activation (None, 56, 56, 224)  0           Dense2_block6_bn1[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_conv1 (Conv2D)    (None, 56, 56, 128)  28672       Dense2_block6_relu1[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_bn2 (BatchNormali (None, 56, 56, 128)  512         Dense2_block6_conv1[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_relu2 (Activation (None, 56, 56, 128)  0           Dense2_block6_bn2[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_zeropadding2 (Zer (None, 58, 58, 128)  0           Dense2_block6_relu2[0][0]
# __________________________________________________________________________________________________
# Dense2_block6_conv2 (Conv2D)    (None, 56, 56, 32)   36864       Dense2_block6_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 32)           0           Dense2_block6_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 32)           0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 2)            66          flatten_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 32)           96          dense_10[0][0]
# __________________________________________________________________________________________________
# tf.reshape_5 (TFOpLambda)       (None, 1, 1, 32)     0           dense_11[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 56, 56, 32)   0           tf.reshape_5[0][0]
#                                                                  Dense2_block6_conv2[0][0]
# __________________________________________________________________________________________________
# Dense2_block6 (Concatenate)     (None, 56, 56, 256)  0           Dense2_block5[0][0]
#                                                                  tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# Trans2_bn (BatchNormalization)  (None, 56, 56, 256)  1024        Dense2_block6[0][0]
# __________________________________________________________________________________________________
# Trans2_relu (Activation)        (None, 56, 56, 256)  0           Trans2_bn[0][0]
# __________________________________________________________________________________________________
# Trans2_conv (Conv2D)            (None, 56, 56, 128)  32768       Trans2_relu[0][0]
# __________________________________________________________________________________________________
# Trans2_pooling2d (AveragePoolin (None, 28, 28, 128)  0           Trans2_conv[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_bn1 (BatchNormali (None, 28, 28, 128)  512         Trans2_pooling2d[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_relu1 (Activation (None, 28, 28, 128)  0           Dense3_block1_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_conv1 (Conv2D)    (None, 28, 28, 128)  16384       Dense3_block1_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block1_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block1_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block1_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block1_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block1_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 32)           0           Dense3_block1_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 32)           0           global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 2)            66          flatten_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 32)           96          dense_12[0][0]
# __________________________________________________________________________________________________
# tf.reshape_6 (TFOpLambda)       (None, 1, 1, 32)     0           dense_13[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) (None, 28, 28, 32)   0           tf.reshape_6[0][0]
#                                                                  Dense3_block1_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block1 (Concatenate)     (None, 28, 28, 160)  0           Trans2_pooling2d[0][0]
#                                                                  tf.math.multiply_6[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_bn1 (BatchNormali (None, 28, 28, 160)  640         Dense3_block1[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_relu1 (Activation (None, 28, 28, 160)  0           Dense3_block2_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_conv1 (Conv2D)    (None, 28, 28, 128)  20480       Dense3_block2_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block2_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block2_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block2_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block2_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block2_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 32)           0           Dense3_block2_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 32)           0           global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 2)            66          flatten_7[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 32)           96          dense_14[0][0]
# __________________________________________________________________________________________________
# tf.reshape_7 (TFOpLambda)       (None, 1, 1, 32)     0           dense_15[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) (None, 28, 28, 32)   0           tf.reshape_7[0][0]
#                                                                  Dense3_block2_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block2 (Concatenate)     (None, 28, 28, 192)  0           Dense3_block1[0][0]
#                                                                  tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_bn1 (BatchNormali (None, 28, 28, 192)  768         Dense3_block2[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_relu1 (Activation (None, 28, 28, 192)  0           Dense3_block3_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_conv1 (Conv2D)    (None, 28, 28, 128)  24576       Dense3_block3_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block3_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block3_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block3_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block3_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block3_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 32)           0           Dense3_block3_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 32)           0           global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 2)            66          flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 32)           96          dense_16[0][0]
# __________________________________________________________________________________________________
# tf.reshape_8 (TFOpLambda)       (None, 1, 1, 32)     0           dense_17[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) (None, 28, 28, 32)   0           tf.reshape_8[0][0]
#                                                                  Dense3_block3_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block3 (Concatenate)     (None, 28, 28, 224)  0           Dense3_block2[0][0]
#                                                                  tf.math.multiply_8[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_bn1 (BatchNormali (None, 28, 28, 224)  896         Dense3_block3[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_relu1 (Activation (None, 28, 28, 224)  0           Dense3_block4_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_conv1 (Conv2D)    (None, 28, 28, 128)  28672       Dense3_block4_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block4_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block4_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block4_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block4_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block4_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 32)           0           Dense3_block4_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 32)           0           global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 2)            66          flatten_9[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 32)           96          dense_18[0][0]
# __________________________________________________________________________________________________
# tf.reshape_9 (TFOpLambda)       (None, 1, 1, 32)     0           dense_19[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_9 (TFOpLambda) (None, 28, 28, 32)   0           tf.reshape_9[0][0]
#                                                                  Dense3_block4_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block4 (Concatenate)     (None, 28, 28, 256)  0           Dense3_block3[0][0]
#                                                                  tf.math.multiply_9[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_bn1 (BatchNormali (None, 28, 28, 256)  1024        Dense3_block4[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_relu1 (Activation (None, 28, 28, 256)  0           Dense3_block5_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_conv1 (Conv2D)    (None, 28, 28, 128)  32768       Dense3_block5_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block5_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block5_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block5_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block5_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block5_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 32)           0           Dense3_block5_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 32)           0           global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 2)            66          flatten_10[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 32)           96          dense_20[0][0]
# __________________________________________________________________________________________________
# tf.reshape_10 (TFOpLambda)      (None, 1, 1, 32)     0           dense_21[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_10 (TFOpLambda (None, 28, 28, 32)   0           tf.reshape_10[0][0]
#                                                                  Dense3_block5_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block5 (Concatenate)     (None, 28, 28, 288)  0           Dense3_block4[0][0]
#                                                                  tf.math.multiply_10[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_bn1 (BatchNormali (None, 28, 28, 288)  1152        Dense3_block5[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_relu1 (Activation (None, 28, 28, 288)  0           Dense3_block6_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_conv1 (Conv2D)    (None, 28, 28, 128)  36864       Dense3_block6_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block6_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block6_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block6_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block6_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block6_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 32)           0           Dense3_block6_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 32)           0           global_average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 2)            66          flatten_11[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 32)           96          dense_22[0][0]
# __________________________________________________________________________________________________
# tf.reshape_11 (TFOpLambda)      (None, 1, 1, 32)     0           dense_23[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_11 (TFOpLambda (None, 28, 28, 32)   0           tf.reshape_11[0][0]
#                                                                  Dense3_block6_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block6 (Concatenate)     (None, 28, 28, 320)  0           Dense3_block5[0][0]
#                                                                  tf.math.multiply_11[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_bn1 (BatchNormali (None, 28, 28, 320)  1280        Dense3_block6[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_relu1 (Activation (None, 28, 28, 320)  0           Dense3_block7_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_conv1 (Conv2D)    (None, 28, 28, 128)  40960       Dense3_block7_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block7_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block7_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block7_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block7_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block7_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_12 (Gl (None, 32)           0           Dense3_block7_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 32)           0           global_average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 2)            66          flatten_12[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 32)           96          dense_24[0][0]
# __________________________________________________________________________________________________
# tf.reshape_12 (TFOpLambda)      (None, 1, 1, 32)     0           dense_25[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_12 (TFOpLambda (None, 28, 28, 32)   0           tf.reshape_12[0][0]
#                                                                  Dense3_block7_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block7 (Concatenate)     (None, 28, 28, 352)  0           Dense3_block6[0][0]
#                                                                  tf.math.multiply_12[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_bn1 (BatchNormali (None, 28, 28, 352)  1408        Dense3_block7[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_relu1 (Activation (None, 28, 28, 352)  0           Dense3_block8_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_conv1 (Conv2D)    (None, 28, 28, 128)  45056       Dense3_block8_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block8_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block8_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block8_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block8_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block8_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_13 (Gl (None, 32)           0           Dense3_block8_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 32)           0           global_average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 2)            66          flatten_13[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 32)           96          dense_26[0][0]
# __________________________________________________________________________________________________
# tf.reshape_13 (TFOpLambda)      (None, 1, 1, 32)     0           dense_27[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_13 (TFOpLambda (None, 28, 28, 32)   0           tf.reshape_13[0][0]
#                                                                  Dense3_block8_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block8 (Concatenate)     (None, 28, 28, 384)  0           Dense3_block7[0][0]
#                                                                  tf.math.multiply_13[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_bn1 (BatchNormali (None, 28, 28, 384)  1536        Dense3_block8[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_relu1 (Activation (None, 28, 28, 384)  0           Dense3_block9_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_conv1 (Conv2D)    (None, 28, 28, 128)  49152       Dense3_block9_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_bn2 (BatchNormali (None, 28, 28, 128)  512         Dense3_block9_conv1[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_relu2 (Activation (None, 28, 28, 128)  0           Dense3_block9_bn2[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_zeropadding2 (Zer (None, 30, 30, 128)  0           Dense3_block9_relu2[0][0]
# __________________________________________________________________________________________________
# Dense3_block9_conv2 (Conv2D)    (None, 28, 28, 32)   36864       Dense3_block9_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_14 (Gl (None, 32)           0           Dense3_block9_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_14 (Flatten)            (None, 32)           0           global_average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 2)            66          flatten_14[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 32)           96          dense_28[0][0]
# __________________________________________________________________________________________________
# tf.reshape_14 (TFOpLambda)      (None, 1, 1, 32)     0           dense_29[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_14 (TFOpLambda (None, 28, 28, 32)   0           tf.reshape_14[0][0]
#                                                                  Dense3_block9_conv2[0][0]
# __________________________________________________________________________________________________
# Dense3_block9 (Concatenate)     (None, 28, 28, 416)  0           Dense3_block8[0][0]
#                                                                  tf.math.multiply_14[0][0]
# __________________________________________________________________________________________________
# Dense3_block10_bn1 (BatchNormal (None, 28, 28, 416)  1664        Dense3_block9[0][0]
# __________________________________________________________________________________________________
# Dense3_block10_relu1 (Activatio (None, 28, 28, 416)  0           Dense3_block10_bn1[0][0]
# __________________________________________________________________________________________________
# Dense3_block10_conv1 (Conv2D)   (None, 28, 28, 128)  53248       Dense3_block10_relu1[0][0]
# __________________________________________________________________________________________________
# Dense3_block10_bn2 (BatchNormal (None, 28, 28, 128)  512         Dense3_block10_conv1[0][0]
# ...
# Dense5_block12_conv2 (Conv2D)   (None, 7, 7, 32)     36864       Dense5_block12_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_53 (Gl (None, 32)           0           Dense5_block12_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_53 (Flatten)            (None, 32)           0           global_average_pooling2d_53[0][0]
# __________________________________________________________________________________________________
# dense_106 (Dense)               (None, 2)            66          flatten_53[0][0]
# __________________________________________________________________________________________________
# dense_107 (Dense)               (None, 32)           96          dense_106[0][0]
# __________________________________________________________________________________________________
# tf.reshape_53 (TFOpLambda)      (None, 1, 1, 32)     0           dense_107[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_53 (TFOpLambda (None, 7, 7, 32)     0           tf.reshape_53[0][0]
#                                                                  Dense5_block12_conv2[0][0]
# __________________________________________________________________________________________________
# Dense5_block12 (Concatenate)    (None, 7, 7, 896)    0           Dense5_block11[0][0]
#                                                                  tf.math.multiply_53[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_bn1 (BatchNormal (None, 7, 7, 896)    3584        Dense5_block12[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_relu1 (Activatio (None, 7, 7, 896)    0           Dense5_block13_bn1[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_conv1 (Conv2D)   (None, 7, 7, 128)    114688      Dense5_block13_relu1[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_bn2 (BatchNormal (None, 7, 7, 128)    512         Dense5_block13_conv1[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_relu2 (Activatio (None, 7, 7, 128)    0           Dense5_block13_bn2[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_zeropadding2 (Ze (None, 9, 9, 128)    0           Dense5_block13_relu2[0][0]
# __________________________________________________________________________________________________
# Dense5_block13_conv2 (Conv2D)   (None, 7, 7, 32)     36864       Dense5_block13_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_54 (Gl (None, 32)           0           Dense5_block13_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_54 (Flatten)            (None, 32)           0           global_average_pooling2d_54[0][0]
# __________________________________________________________________________________________________
# dense_108 (Dense)               (None, 2)            66          flatten_54[0][0]
# __________________________________________________________________________________________________
# dense_109 (Dense)               (None, 32)           96          dense_108[0][0]
# __________________________________________________________________________________________________
# tf.reshape_54 (TFOpLambda)      (None, 1, 1, 32)     0           dense_109[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_54 (TFOpLambda (None, 7, 7, 32)     0           tf.reshape_54[0][0]
#                                                                  Dense5_block13_conv2[0][0]
# __________________________________________________________________________________________________
# Dense5_block13 (Concatenate)    (None, 7, 7, 928)    0           Dense5_block12[0][0]
#                                                                  tf.math.multiply_54[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_bn1 (BatchNormal (None, 7, 7, 928)    3712        Dense5_block13[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_relu1 (Activatio (None, 7, 7, 928)    0           Dense5_block14_bn1[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_conv1 (Conv2D)   (None, 7, 7, 128)    118784      Dense5_block14_relu1[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_bn2 (BatchNormal (None, 7, 7, 128)    512         Dense5_block14_conv1[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_relu2 (Activatio (None, 7, 7, 128)    0           Dense5_block14_bn2[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_zeropadding2 (Ze (None, 9, 9, 128)    0           Dense5_block14_relu2[0][0]
# __________________________________________________________________________________________________
# Dense5_block14_conv2 (Conv2D)   (None, 7, 7, 32)     36864       Dense5_block14_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_55 (Gl (None, 32)           0           Dense5_block14_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_55 (Flatten)            (None, 32)           0           global_average_pooling2d_55[0][0]
# __________________________________________________________________________________________________
# dense_110 (Dense)               (None, 2)            66          flatten_55[0][0]
# __________________________________________________________________________________________________
# dense_111 (Dense)               (None, 32)           96          dense_110[0][0]
# __________________________________________________________________________________________________
# tf.reshape_55 (TFOpLambda)      (None, 1, 1, 32)     0           dense_111[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_55 (TFOpLambda (None, 7, 7, 32)     0           tf.reshape_55[0][0]
#                                                                  Dense5_block14_conv2[0][0]
# __________________________________________________________________________________________________
# Dense5_block14 (Concatenate)    (None, 7, 7, 960)    0           Dense5_block13[0][0]
#                                                                  tf.math.multiply_55[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_bn1 (BatchNormal (None, 7, 7, 960)    3840        Dense5_block14[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_relu1 (Activatio (None, 7, 7, 960)    0           Dense5_block15_bn1[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_conv1 (Conv2D)   (None, 7, 7, 128)    122880      Dense5_block15_relu1[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_bn2 (BatchNormal (None, 7, 7, 128)    512         Dense5_block15_conv1[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_relu2 (Activatio (None, 7, 7, 128)    0           Dense5_block15_bn2[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_zeropadding2 (Ze (None, 9, 9, 128)    0           Dense5_block15_relu2[0][0]
# __________________________________________________________________________________________________
# Dense5_block15_conv2 (Conv2D)   (None, 7, 7, 32)     36864       Dense5_block15_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_56 (Gl (None, 32)           0           Dense5_block15_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_56 (Flatten)            (None, 32)           0           global_average_pooling2d_56[0][0]
# __________________________________________________________________________________________________
# dense_112 (Dense)               (None, 2)            66          flatten_56[0][0]
# __________________________________________________________________________________________________
# dense_113 (Dense)               (None, 32)           96          dense_112[0][0]
# __________________________________________________________________________________________________
# tf.reshape_56 (TFOpLambda)      (None, 1, 1, 32)     0           dense_113[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_56 (TFOpLambda (None, 7, 7, 32)     0           tf.reshape_56[0][0]
#                                                                  Dense5_block15_conv2[0][0]
# __________________________________________________________________________________________________
# Dense5_block15 (Concatenate)    (None, 7, 7, 992)    0           Dense5_block14[0][0]
#                                                                  tf.math.multiply_56[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_bn1 (BatchNormal (None, 7, 7, 992)    3968        Dense5_block15[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_relu1 (Activatio (None, 7, 7, 992)    0           Dense5_block16_bn1[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_conv1 (Conv2D)   (None, 7, 7, 128)    126976      Dense5_block16_relu1[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_bn2 (BatchNormal (None, 7, 7, 128)    512         Dense5_block16_conv1[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_relu2 (Activatio (None, 7, 7, 128)    0           Dense5_block16_bn2[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_zeropadding2 (Ze (None, 9, 9, 128)    0           Dense5_block16_relu2[0][0]
# __________________________________________________________________________________________________
# Dense5_block16_conv2 (Conv2D)   (None, 7, 7, 32)     36864       Dense5_block16_zeropadding2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_57 (Gl (None, 32)           0           Dense5_block16_conv2[0][0]
# __________________________________________________________________________________________________
# flatten_57 (Flatten)            (None, 32)           0           global_average_pooling2d_57[0][0]
# __________________________________________________________________________________________________
# dense_114 (Dense)               (None, 2)            66          flatten_57[0][0]
# __________________________________________________________________________________________________
# dense_115 (Dense)               (None, 32)           96          dense_114[0][0]
# __________________________________________________________________________________________________
# tf.reshape_57 (TFOpLambda)      (None, 1, 1, 32)     0           dense_115[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_57 (TFOpLambda (None, 7, 7, 32)     0           tf.reshape_57[0][0]
#                                                                  Dense5_block16_conv2[0][0]
# __________________________________________________________________________________________________
# Dense5_block16 (Concatenate)    (None, 7, 7, 1024)   0           Dense5_block15[0][0]
#                                                                  tf.math.multiply_57[0][0]
# __________________________________________________________________________________________________
# final_conv_bn (BatchNormalizati (None, 7, 7, 1024)   4096        Dense5_block16[0][0]
# __________________________________________________________________________________________________
# final_act (Activation)          (None, 7, 7, 1024)   0           final_conv_bn[0][0]
# __________________________________________________________________________________________________
# final_pooling (GlobalAveragePoo (None, 1024)         0           final_act[0][0]
# __________________________________________________________________________________________________
# dense_116 (Dense)               (None, 512)          524800      final_pooling[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense_116[0][0]
# __________________________________________________________________________________________________
# dense_117 (Dense)               (None, 3)            1539        dropout[0][0]
# ==================================================================================================
# Total params: 7,573,239
# Trainable params: 7,489,591
# Non-trainable params: 83,648
# __________________________________________________________________________________________________
# 2023-01-10 18:28:46.566692: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2023-01-10 18:28:46.566728: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2023-01-10 18:28:46.566775: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1614] Profiler found 1 GPUs
# 2023-01-10 18:28:46.567321: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /root/miniconda3/lib/python3.8/site-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-01-10 18:28:46.782085: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2023-01-10 18:28:46.782279: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed

# %%
reduce_LR = ReduceLROnPlateau(monitor="val_loss", 
                             factor = 0.5, 
                             patience = 2, 
                             min_delta=0.001, 
                             mode = "auto", 
                            verbose = 1)

# %%
history = model.fit(X_train, Y_train,
                  validation_split =0.1,
                  epochs =100, 
                  verbose =1, 
                  batch_size = 32, 
                  callbacks = [tensorboard, checkpoint, reduce_LR])
# Out:
# 2023-01-10 18:29:20.467769: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2023-01-10 18:29:40.578961: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8400
# 2023-01-10 18:29:42.538579: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
#   1/648 [..............................] - ETA: 4:15:59 - loss: 1.3198 - accuracy: 0.4062
# 2023-01-10 18:29:44.940714: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2023-01-10 18:29:44.940743: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
#   2/648 [..............................] - ETA: 22:17 - loss: 1.6993 - accuracy: 0.2969
# 2023-01-10 18:29:46.302791: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2023-01-10 18:29:46.303773: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed
# 2023-01-10 18:29:46.400377: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:673]  GpuTracer has collected 4608 callback api events and 4629 activity events.
# 2023-01-10 18:29:46.550213: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2023-01-10 18:29:46.710450: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: AD-CN-MCI-SE-Denseblock-SE/train/plugins/profile/2023_01_10_18_29_46
#
# 2023-01-10 18:29:46.821670: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to AD-CN-MCI-SE-Denseblock-SE/train/plugins/profile/2023_01_10_18_29_46/autodl-container-33ed11913c-1884a065.trace.json.gz
#   3/648 [..............................] - ETA: 16:04 - loss: 1.7801 - accuracy: 0.3438
# 2023-01-10 18:29:47.025535: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: AD-CN-MCI-SE-Denseblock-SE/train/plugins/profile/2023_01_10_18_29_46
#
# 2023-01-10 18:29:47.035777: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to AD-CN-MCI-SE-Denseblock-SE/train/plugins/profile/2023_01_10_18_29_46/autodl-container-33ed11913c-1884a065.memory_profile.json.gz
# 2023-01-10 18:29:47.045910: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: AD-CN-MCI-SE-Denseblock-SE/train/plugins/profile/2023_01_10_18_29_46
# Dumped tool data for xplane.pb to AD-CN-MCI-SE-Denseblock-SE/train/plugins/profile/2023_01_10_18_29_46/autodl-container-33ed11913c-1884a065.xplane.pb
# Dumped tool data for overview_page.pb to AD-CN-MCI-SE-Denseblock-SE/train/plugins/profile/2023_01_10_18_29_46/autodl-container-33ed11913c-1884a065.overview_page.pb
# Dumped tool data for input_pipeline.pb to AD-CN-MCI-SE-Denseblock-SE/train/plugins/profile/2023_01_10_18_29_46/autodl-container-33ed11913c-1884a065.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to AD-CN-MCI-SE-Denseblock-SE/train/plugins/profile/2023_01_10_18_29_46/autodl-container-33ed11913c-1884a065.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to AD-CN-MCI-SE-Denseblock-SE/train/plugins/profile/2023_01_10_18_29_46/autodl-container-33ed11913c-1884a065.kernel_stats.pb
# 648/648 [==============================] - 119s 147ms/step - loss: 1.0572 - accuracy: 0.4494 - val_loss: 1.1044 - val_accuracy: 0.3529
#
# Epoch 00001: val_accuracy improved from -inf to 0.35286, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 2/100
# 648/648 [==============================] - 88s 136ms/step - loss: 1.0254 - accuracy: 0.4697 - val_loss: 1.1043 - val_accuracy: 0.3932
#
# Epoch 00002: val_accuracy improved from 0.35286 to 0.39323, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 3/100
# 648/648 [==============================] - 89s 137ms/step - loss: 1.0037 - accuracy: 0.4892 - val_loss: 1.1184 - val_accuracy: 0.3589
#
# Epoch 00003: val_accuracy did not improve from 0.39323
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 4/100
# 648/648 [==============================] - 87s 134ms/step - loss: 0.9713 - accuracy: 0.5138 - val_loss: 1.8278 - val_accuracy: 0.3477
#
# Epoch 00004: val_accuracy did not improve from 0.39323
# Epoch 5/100
# 648/648 [==============================] - 86s 133ms/step - loss: 0.9573 - accuracy: 0.5253 - val_loss: 0.9695 - val_accuracy: 0.5230
#
# Epoch 00005: val_accuracy improved from 0.39323 to 0.52300, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 6/100
# 648/648 [==============================] - 86s 132ms/step - loss: 0.9320 - accuracy: 0.5379 - val_loss: 0.9475 - val_accuracy: 0.5456
#
# Epoch 00006: val_accuracy improved from 0.52300 to 0.54557, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 7/100
# 648/648 [==============================] - 86s 133ms/step - loss: 0.9061 - accuracy: 0.5503 - val_loss: 0.9660 - val_accuracy: 0.4983
#
# Epoch 00007: val_accuracy did not improve from 0.54557
# Epoch 8/100
# 648/648 [==============================] - 86s 133ms/step - loss: 0.8763 - accuracy: 0.5730 - val_loss: 1.1941 - val_accuracy: 0.4293
#
# Epoch 00008: val_accuracy did not improve from 0.54557
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 9/100
# 648/648 [==============================] - 84s 130ms/step - loss: 0.7849 - accuracy: 0.6231 - val_loss: 0.8636 - val_accuracy: 0.5938
#
# Epoch 00009: val_accuracy improved from 0.54557 to 0.59375, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 10/100
# 648/648 [==============================] - 85s 131ms/step - loss: 0.7101 - accuracy: 0.6693 - val_loss: 1.1672 - val_accuracy: 0.4679
#
# Epoch 00010: val_accuracy did not improve from 0.59375
# Epoch 11/100
# 648/648 [==============================] - 85s 131ms/step - loss: 0.6349 - accuracy: 0.7166 - val_loss: 1.1801 - val_accuracy: 0.4805
#
# Epoch 00011: val_accuracy did not improve from 0.59375
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 12/100
# 648/648 [==============================] - 86s 132ms/step - loss: 0.4821 - accuracy: 0.7985 - val_loss: 0.6433 - val_accuracy: 0.7179
#
# Epoch 00012: val_accuracy improved from 0.59375 to 0.71788, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 13/100
# 648/648 [==============================] - 86s 132ms/step - loss: 0.3838 - accuracy: 0.8505 - val_loss: 0.7676 - val_accuracy: 0.7457
#
# Epoch 00013: val_accuracy improved from 0.71788 to 0.74566, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 14/100
# 648/648 [==============================] - 85s 131ms/step - loss: 0.3114 - accuracy: 0.8804 - val_loss: 0.7527 - val_accuracy: 0.7339
#
# Epoch 00014: val_accuracy did not improve from 0.74566
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 15/100
# 648/648 [==============================] - 84s 130ms/step - loss: 0.1957 - accuracy: 0.9295 - val_loss: 0.4599 - val_accuracy: 0.8372
#
# Epoch 00015: val_accuracy improved from 0.74566 to 0.83724, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 16/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.1576 - accuracy: 0.9450 - val_loss: 0.5784 - val_accuracy: 0.8142
#
# Epoch 00016: val_accuracy did not improve from 0.83724
# Epoch 17/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.1301 - accuracy: 0.9542 - val_loss: 0.4120 - val_accuracy: 0.8728
#
# Epoch 00017: val_accuracy improved from 0.83724 to 0.87283, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 18/100
# 648/648 [==============================] - 83s 129ms/step - loss: 0.1121 - accuracy: 0.9620 - val_loss: 0.6149 - val_accuracy: 0.8377
#
# Epoch 00018: val_accuracy did not improve from 0.87283
# Epoch 19/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.1007 - accuracy: 0.9659 - val_loss: 0.4024 - val_accuracy: 0.8806
#
# Epoch 00019: val_accuracy improved from 0.87283 to 0.88064, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 20/100
# 648/648 [==============================] - 83s 129ms/step - loss: 0.0814 - accuracy: 0.9730 - val_loss: 0.8060 - val_accuracy: 0.7808
#
# Epoch 00020: val_accuracy did not improve from 0.88064
# Epoch 21/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0812 - accuracy: 0.9731 - val_loss: 0.5090 - val_accuracy: 0.8724
#
# Epoch 00021: val_accuracy did not improve from 0.88064
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 22/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0499 - accuracy: 0.9853 - val_loss: 0.3881 - val_accuracy: 0.8906
#
# Epoch 00022: val_accuracy improved from 0.88064 to 0.89062, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 23/100
# 648/648 [==============================] - 83s 129ms/step - loss: 0.0410 - accuracy: 0.9872 - val_loss: 0.6003 - val_accuracy: 0.8451
#
# Epoch 00023: val_accuracy did not improve from 0.89062
# Epoch 24/100
# 648/648 [==============================] - 83s 129ms/step - loss: 0.0415 - accuracy: 0.9877 - val_loss: 0.4080 - val_accuracy: 0.8980
#
# Epoch 00024: val_accuracy improved from 0.89062 to 0.89800, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 25/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0251 - accuracy: 0.9941 - val_loss: 0.3611 - val_accuracy: 0.9149
#
# Epoch 00025: val_accuracy improved from 0.89800 to 0.91493, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 26/100
# 648/648 [==============================] - 82s 127ms/step - loss: 0.0226 - accuracy: 0.9943 - val_loss: 0.4187 - val_accuracy: 0.9071
#
# Epoch 00026: val_accuracy did not improve from 0.91493
# Epoch 27/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0227 - accuracy: 0.9934 - val_loss: 0.3519 - val_accuracy: 0.9236
#
# Epoch 00027: val_accuracy improved from 0.91493 to 0.92361, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 28/100
# 648/648 [==============================] - 82s 126ms/step - loss: 0.0188 - accuracy: 0.9950 - val_loss: 0.3856 - val_accuracy: 0.9180
#
# Epoch 00028: val_accuracy did not improve from 0.92361
# Epoch 29/100
# 648/648 [==============================] - 82s 127ms/step - loss: 0.0189 - accuracy: 0.9946 - val_loss: 0.4125 - val_accuracy: 0.9089
#
# Epoch 00029: val_accuracy did not improve from 0.92361
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 30/100
# 648/648 [==============================] - 82s 126ms/step - loss: 0.0176 - accuracy: 0.9952 - val_loss: 0.3658 - val_accuracy: 0.9249
#
# Epoch 00030: val_accuracy improved from 0.92361 to 0.92491, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 31/100
# 648/648 [==============================] - 82s 127ms/step - loss: 0.0148 - accuracy: 0.9965 - val_loss: 0.3783 - val_accuracy: 0.9245
#
# Epoch 00031: val_accuracy did not improve from 0.92491
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 32/100
# 648/648 [==============================] - 82s 126ms/step - loss: 0.0140 - accuracy: 0.9965 - val_loss: 0.3694 - val_accuracy: 0.9262
#
# Epoch 00032: val_accuracy improved from 0.92491 to 0.92622, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
# Epoch 33/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0107 - accuracy: 0.9977 - val_loss: 0.3754 - val_accuracy: 0.9271
#
# Epoch 00033: val_accuracy improved from 0.92622 to 0.92708, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 34/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0117 - accuracy: 0.9973 - val_loss: 0.3829 - val_accuracy: 0.9253
#
# Epoch 00034: val_accuracy did not improve from 0.92708
# Epoch 35/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0126 - accuracy: 0.9968 - val_loss: 0.3816 - val_accuracy: 0.9288
#
# Epoch 00035: val_accuracy improved from 0.92708 to 0.92882, saving model to AD-CN-MCI-SE-Denseblock-SE.h5
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 36/100
# 648/648 [==============================] - 82s 126ms/step - loss: 0.0127 - accuracy: 0.9970 - val_loss: 0.3787 - val_accuracy: 0.9280
#
# Epoch 00036: val_accuracy did not improve from 0.92882
# Epoch 37/100
# 648/648 [==============================] - 82s 127ms/step - loss: 0.0099 - accuracy: 0.9976 - val_loss: 0.3716 - val_accuracy: 0.9280
#
# Epoch 00037: val_accuracy did not improve from 0.92882
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 38/100
# 648/648 [==============================] - 82s 127ms/step - loss: 0.0103 - accuracy: 0.9979 - val_loss: 0.3768 - val_accuracy: 0.9284
#
# Epoch 00038: val_accuracy did not improve from 0.92882
# Epoch 39/100
# 648/648 [==============================] - 82s 127ms/step - loss: 0.0125 - accuracy: 0.9969 - val_loss: 0.3789 - val_accuracy: 0.9262
#
# Epoch 00039: val_accuracy did not improve from 0.92882
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 40/100
# 648/648 [==============================] - 83s 127ms/step - loss: 0.0117 - accuracy: 0.9981 - val_loss: 0.3772 - val_accuracy: 0.9271
#
# Epoch 00040: val_accuracy did not improve from 0.92882
# Epoch 41/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0097 - accuracy: 0.9980 - val_loss: 0.3783 - val_accuracy: 0.9280
#
# Epoch 00041: val_accuracy did not improve from 0.92882
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 42/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0127 - accuracy: 0.9966 - val_loss: 0.3732 - val_accuracy: 0.9284
#
# Epoch 00042: val_accuracy did not improve from 0.92882
# Epoch 43/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0100 - accuracy: 0.9979 - val_loss: 0.3789 - val_accuracy: 0.9271
#
# Epoch 00043: val_accuracy did not improve from 0.92882
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 44/100
# 648/648 [==============================] - 83s 129ms/step - loss: 0.0097 - accuracy: 0.9981 - val_loss: 0.3810 - val_accuracy: 0.9271
#
# Epoch 00044: val_accuracy did not improve from 0.92882
# Epoch 45/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0113 - accuracy: 0.9975 - val_loss: 0.3754 - val_accuracy: 0.9271
#
# Epoch 00045: val_accuracy did not improve from 0.92882
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 46/100
# 648/648 [==============================] - 83s 127ms/step - loss: 0.0100 - accuracy: 0.9980 - val_loss: 0.3783 - val_accuracy: 0.9275
#
# Epoch 00046: val_accuracy did not improve from 0.92882
# Epoch 47/100
# 648/648 [==============================] - 83s 129ms/step - loss: 0.0122 - accuracy: 0.9973 - val_loss: 0.3757 - val_accuracy: 0.9280
#
# Epoch 00047: val_accuracy did not improve from 0.92882
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 48/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0120 - accuracy: 0.9973 - val_loss: 0.3747 - val_accuracy: 0.9271
#
# Epoch 00048: val_accuracy did not improve from 0.92882
# Epoch 49/100
# 648/648 [==============================] - 82s 127ms/step - loss: 0.0104 - accuracy: 0.9983 - val_loss: 0.3778 - val_accuracy: 0.9271
#
# Epoch 00049: val_accuracy did not improve from 0.92882
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 50/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0109 - accuracy: 0.9974 - val_loss: 0.3830 - val_accuracy: 0.9280
#
# Epoch 00050: val_accuracy did not improve from 0.92882
# Epoch 51/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0108 - accuracy: 0.9976 - val_loss: 0.3718 - val_accuracy: 0.9280
#
# Epoch 00051: val_accuracy did not improve from 0.92882
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 52/100
# 648/648 [==============================] - 84s 130ms/step - loss: 0.0121 - accuracy: 0.9967 - val_loss: 0.3750 - val_accuracy: 0.9275
#
# Epoch 00052: val_accuracy did not improve from 0.92882
# Epoch 53/100
# 648/648 [==============================] - 84s 130ms/step - loss: 0.0095 - accuracy: 0.9980 - val_loss: 0.3800 - val_accuracy: 0.9271
#
# Epoch 00053: val_accuracy did not improve from 0.92882
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# Epoch 54/100
# 648/648 [==============================] - 84s 130ms/step - loss: 0.0098 - accuracy: 0.9984 - val_loss: 0.3730 - val_accuracy: 0.9284
#
# Epoch 00054: val_accuracy did not improve from 0.92882
# Epoch 55/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0105 - accuracy: 0.9979 - val_loss: 0.3771 - val_accuracy: 0.9271
#
# Epoch 00055: val_accuracy did not improve from 0.92882
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# Epoch 56/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0105 - accuracy: 0.9977 - val_loss: 0.3795 - val_accuracy: 0.9275
#
# Epoch 00056: val_accuracy did not improve from 0.92882
# Epoch 57/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0120 - accuracy: 0.9969 - val_loss: 0.3747 - val_accuracy: 0.9271
#
# Epoch 00057: val_accuracy did not improve from 0.92882
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 4.768371808516747e-10.
# Epoch 58/100
# 648/648 [==============================] - 82s 127ms/step - loss: 0.0090 - accuracy: 0.9981 - val_loss: 0.3859 - val_accuracy: 0.9266
#
# Epoch 00058: val_accuracy did not improve from 0.92882
# Epoch 59/100
# 648/648 [==============================] - 83s 129ms/step - loss: 0.0087 - accuracy: 0.9985 - val_loss: 0.3726 - val_accuracy: 0.9284
#
# Epoch 00059: val_accuracy did not improve from 0.92882
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 2.3841859042583735e-10.
# Epoch 60/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0105 - accuracy: 0.9973 - val_loss: 0.3788 - val_accuracy: 0.9275
#
# Epoch 00060: val_accuracy did not improve from 0.92882
# Epoch 61/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0106 - accuracy: 0.9978 - val_loss: 0.3731 - val_accuracy: 0.9280
#
# Epoch 00061: val_accuracy did not improve from 0.92882
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 1.1920929521291868e-10.
# Epoch 62/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0096 - accuracy: 0.9979 - val_loss: 0.3782 - val_accuracy: 0.9275
#
# Epoch 00062: val_accuracy did not improve from 0.92882
# Epoch 63/100
# 648/648 [==============================] - 82s 126ms/step - loss: 0.0114 - accuracy: 0.9976 - val_loss: 0.3807 - val_accuracy: 0.9280
#
# Epoch 00063: val_accuracy did not improve from 0.92882
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 5.960464760645934e-11.
# Epoch 64/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0093 - accuracy: 0.9983 - val_loss: 0.3818 - val_accuracy: 0.9275
#
# Epoch 00064: val_accuracy did not improve from 0.92882
# Epoch 65/100
# 648/648 [==============================] - 84s 130ms/step - loss: 0.0120 - accuracy: 0.9976 - val_loss: 0.3820 - val_accuracy: 0.9284
#
# Epoch 00065: val_accuracy did not improve from 0.92882
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 2.980232380322967e-11.
# Epoch 66/100
# 648/648 [==============================] - 82s 127ms/step - loss: 0.0113 - accuracy: 0.9978 - val_loss: 0.3710 - val_accuracy: 0.9280
#
# Epoch 00066: val_accuracy did not improve from 0.92882
# Epoch 67/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0106 - accuracy: 0.9976 - val_loss: 0.3767 - val_accuracy: 0.9275
#
# Epoch 00067: val_accuracy did not improve from 0.92882
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 1.4901161901614834e-11.
# Epoch 68/100
# 648/648 [==============================] - 82s 126ms/step - loss: 0.0099 - accuracy: 0.9983 - val_loss: 0.3779 - val_accuracy: 0.9275
#
# Epoch 00068: val_accuracy did not improve from 0.92882
# Epoch 69/100
# 648/648 [==============================] - 82s 127ms/step - loss: 0.0098 - accuracy: 0.9976 - val_loss: 0.3787 - val_accuracy: 0.9266
#
# Epoch 00069: val_accuracy did not improve from 0.92882
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 7.450580950807417e-12.
# Epoch 70/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0098 - accuracy: 0.9979 - val_loss: 0.3781 - val_accuracy: 0.9275
#
# Epoch 00070: val_accuracy did not improve from 0.92882
# Epoch 71/100
# 648/648 [==============================] - 83s 127ms/step - loss: 0.0111 - accuracy: 0.9974 - val_loss: 0.3757 - val_accuracy: 0.9275
#
# Epoch 00071: val_accuracy did not improve from 0.92882
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 3.725290475403709e-12.
# Epoch 72/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0130 - accuracy: 0.9966 - val_loss: 0.3794 - val_accuracy: 0.9275
#
# Epoch 00072: val_accuracy did not improve from 0.92882
# Epoch 73/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0094 - accuracy: 0.9983 - val_loss: 0.3773 - val_accuracy: 0.9288
#
# Epoch 00073: val_accuracy did not improve from 0.92882
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 1.8626452377018543e-12.
# Epoch 74/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0091 - accuracy: 0.9982 - val_loss: 0.3747 - val_accuracy: 0.9275
#
# Epoch 00074: val_accuracy did not improve from 0.92882
# Epoch 75/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0092 - accuracy: 0.9983 - val_loss: 0.3814 - val_accuracy: 0.9275
#
# Epoch 00075: val_accuracy did not improve from 0.92882
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 9.313226188509272e-13.
# Epoch 76/100
# 648/648 [==============================] - 83s 129ms/step - loss: 0.0097 - accuracy: 0.9982 - val_loss: 0.3723 - val_accuracy: 0.9284
#
# Epoch 00076: val_accuracy did not improve from 0.92882
# Epoch 77/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.3803 - val_accuracy: 0.9271
#
# Epoch 00077: val_accuracy did not improve from 0.92882
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 4.656613094254636e-13.
# Epoch 78/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0100 - accuracy: 0.9980 - val_loss: 0.3822 - val_accuracy: 0.9271
#
# Epoch 00078: val_accuracy did not improve from 0.92882
# Epoch 79/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0106 - accuracy: 0.9977 - val_loss: 0.3761 - val_accuracy: 0.9280
#
# Epoch 00079: val_accuracy did not improve from 0.92882
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 2.328306547127318e-13.
# Epoch 80/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0144 - accuracy: 0.9965 - val_loss: 0.3803 - val_accuracy: 0.9271
#
# Epoch 00080: val_accuracy did not improve from 0.92882
# Epoch 81/100
# 648/648 [==============================] - 84s 129ms/step - loss: 0.0094 - accuracy: 0.9981 - val_loss: 0.3763 - val_accuracy: 0.9284
#
# Epoch 00081: val_accuracy did not improve from 0.92882
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 1.164153273563659e-13.
# Epoch 82/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0110 - accuracy: 0.9978 - val_loss: 0.3707 - val_accuracy: 0.9275
#
# Epoch 00082: val_accuracy did not improve from 0.92882
# Epoch 83/100
# 648/648 [==============================] - 83s 128ms/step - loss: 0.0102 - accuracy: 0.9977 - val_loss: 0.3812 - val_accuracy: 0.9266
#
# Epoch 00083: val_accuracy did not improve from 0.92882
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 5.820766367818295e-14.
# Epoch 84/100
# 648/648 [==============================] - 83s 127ms/step - loss: 0.0098 - accuracy: 0.9978 - val_loss: 0.3766 - val_accuracy: 0.9275
#
# Epoch 00084: val_accuracy did not improve from 0.92882
# Epoch 85/100
# 648/648 [==============================] - 83s 129ms/step - loss: 0.0111 - accuracy: 0.9977 - val_loss: 0.3841 - val_accuracy: 0.9271
#
# Epoch 00085: val_accuracy did not improve from 0.92882
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 2.9103831839091474e-14.
# Epoch 86/100
# 648/648 [==============================] - 83s 127ms/step - loss: 0.0106 - accuracy: 0.9977 - val_loss: 0.3729 - val_accuracy: 0.9275
#
# Epoch 00086: val_accuracy did not improve from 0.92882
# Epoch 87/100
# 648/648 [==============================] - 82s 127ms/step - loss: 0.0129 - accuracy: 0.9969 - val_loss: 0.3776 - val_accuracy: 0.9280
#
# Epoch 00087: val_accuracy did not improve from 0.92882
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1.4551915919545737e-14.
# Epoch 88/100
# 648/648 [==============================] - 82s 127ms/step - loss: 0.0107 - accuracy: 0.9973 - val_loss: 0.3736 - val_accuracy: 0.9280
#
# Epoch 00088: val_accuracy did not improve from 0.92882
# Epoch 89/100
# 648/648 [==============================] - 83s 127ms/step - loss: 0.0105 - accuracy: 0.9981 - val_loss: 0.3749 - val_accuracy: 0.9275
#
# Epoch 00089: val_accuracy did not improve from 0.92882
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 7.275957959772868e-15.
# Epoch 90/100
# 648/648 [==============================] - 82s 126ms/step - loss: 0.0104 - accuracy: 0.9973 - val_loss: 0.3740 - val_accuracy: 0.9275
#
# Epoch 00090: val_accuracy did not improve from 0.92882
# Epoch 91/100
# 648/648 [==============================] - 82s 126ms/step - loss: 0.0096 - accuracy: 0.9983 - val_loss: 0.3761 - val_accuracy: 0.9275
#
# Epoch 00091: val_accuracy did not improve from 0.92882
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 3.637978979886434e-15.
# Epoch 92/100
# 648/648 [==============================] - 80s 123ms/step - loss: 0.0126 - accuracy: 0.9968 - val_loss: 0.3751 - val_accuracy: 0.9271
#
# Epoch 00092: val_accuracy did not improve from 0.92882
# Epoch 93/100
# 648/648 [==============================] - 80s 124ms/step - loss: 0.0102 - accuracy: 0.9978 - val_loss: 0.3908 - val_accuracy: 0.9262
#
# Epoch 00093: val_accuracy did not improve from 0.92882
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 1.818989489943217e-15.
# Epoch 94/100
# 648/648 [==============================] - 80s 124ms/step - loss: 0.0106 - accuracy: 0.9978 - val_loss: 0.3709 - val_accuracy: 0.9275
#
# Epoch 00094: val_accuracy did not improve from 0.92882
# Epoch 95/100
# 648/648 [==============================] - 81s 126ms/step - loss: 0.0098 - accuracy: 0.9978 - val_loss: 0.3833 - val_accuracy: 0.9275
#
# Epoch 00095: val_accuracy did not improve from 0.92882
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 9.094947449716085e-16.
# Epoch 96/100
# 648/648 [==============================] - 81s 125ms/step - loss: 0.0108 - accuracy: 0.9979 - val_loss: 0.3754 - val_accuracy: 0.9275
#
# Epoch 00096: val_accuracy did not improve from 0.92882
# Epoch 97/100
# 648/648 [==============================] - 80s 123ms/step - loss: 0.0095 - accuracy: 0.9983 - val_loss: 0.3759 - val_accuracy: 0.9271
#
# Epoch 00097: val_accuracy did not improve from 0.92882
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 4.547473724858043e-16.
# Epoch 98/100
# 648/648 [==============================] - 79s 122ms/step - loss: 0.0110 - accuracy: 0.9973 - val_loss: 0.3804 - val_accuracy: 0.9280
#
# Epoch 00098: val_accuracy did not improve from 0.92882
# Epoch 99/100
# 648/648 [==============================] - 80s 124ms/step - loss: 0.0089 - accuracy: 0.9983 - val_loss: 0.3809 - val_accuracy: 0.9266
#
# Epoch 00099: val_accuracy did not improve from 0.92882
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 2.2737368624290214e-16.
# Epoch 100/100
# 648/648 [==============================] - 80s 124ms/step - loss: 0.0103 - accuracy: 0.9981 - val_loss: 0.3837 - val_accuracy: 0.9284
#
# Epoch 00100: val_accuracy did not improve from 0.92882

# %%
def accuracy_lr_loss_plot (history):
    fig = plt.figure(figsize=(15,10))
    
    plt.subplot(221)
    plt.plot(history.history["loss"], "bo--", label="loss")
    plt.plot(history.history["val_loss"], "ro--", label = "val_loss")
    plt.title("Training Data Loss")
    plt.xlabel("Number of epochs")
    plt.ylabel("loss")
    plt.grid()
    plt.legend()
    plt.tight_layout()
    
    plt.subplot(222)
    plt.plot(history.history["accuracy"], 'bo--', label="accuracy")
    plt.plot(history.history['val_accuracy'], 'ro--', label="val_accuracy")
    plt.title("Training Data Accuracy Measurements")
    plt.xlabel("Number of epochs")
    plt.ylabel("Accuracy")
    plt.grid()
    plt.legend()
    plt.tight_layout()
    
   
    
    plt.show()

# %%
accuracy_lr_loss_plot(history)

# %%
result= model.evaluate(X_test,Y_test,batch_size=32)
print("Accuracy is\n",result)
# Out:
# 180/180 [==============================] - 8s 39ms/step - loss: 0.3503 - accuracy: 0.9269
# Accuracy is
#  [0.3503195345401764, 0.9269097447395325]

# %% [markdown]
# ### 绘制混淆矩阵及特异-敏感性分析

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import glob
import tensorflow as tf
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.models import load_model

model = load_model("AD-CN-MCI-SE-Denseblock-SE.h5")

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

labels = ["AD", "CN", "MCI"]

y_pred = model.predict(X_test)
y_pred=np.argmax(y_pred, axis=1)
y_test_new = np.argmax(Y_test, axis=1)
target_names = labels

# %%
print(classification_report(y_test_new, y_pred,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#           AD       0.96      0.92      0.94      1913
#           CN       0.97      0.92      0.94      1891
#          MCI       0.86      0.94      0.90      1956
#
#     accuracy                           0.93      5760
#    macro avg       0.93      0.93      0.93      5760
# weighted avg       0.93      0.93      0.93      5760

# %%
cm=confusion_matrix(y_test_new, y_pred)
display_c_m = ConfusionMatrixDisplay(cm, display_labels=labels)
fig, ax = plt.subplots(figsize=(25,10)) 
display_c_m.plot(cmap='mako',ax=ax,xticks_rotation=60)
plt.title("Confusion Metrics")
plt.show()

# %%
Sensitivity = cm[0][0] / (cm[0][0] + cm[0][1])
Specificity = cm[1][1] / (cm[1][0] + cm[1][1])
print("Sensitivity: " + str(Sensitivity))
print("Specificity: " + str(Specificity))
# Out:
# Sensitivity: 0.9982944855031268
# Specificity: 1.0

# %%
# 在医学统计里，任何一个诊断指标，都有两个最基本的特征，即敏感性和特异性。
# 所谓敏感性，就是指其在诊断疾病的时候不漏诊的机会有多大，所谓特异性就是指该指标在诊断某疾病时，不误诊的机会有多大。
# 单独一个指标，如果提高其诊断的敏感性，必然降低其诊断的特异性，换句话说，减少漏诊必然增加误诊，反之亦然

# %%
from sklearn.metrics import precision_recall_fscore_support

res = []
for i in labels:
    prec, recall, _, _ = precision_recall_fscore_support(np.array(y_test_new)==1,
                                                         np.array(y_pred)==1,
                                                         pos_label=True, average=None)
    
    res.append([i, recall[0], recall[1]])

pd.DataFrame(res, columns = ["class", "sensitivity", "specificity"])
# Out:
#   class  sensitivity  specificity
# 0    AD     0.983975      0.92385
# 1    CN     0.983975      0.92385
# 2   MCI     0.983975      0.92385

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score
acc = accuracy_score(y_test_new, y_pred)
pre = precision_score(y_test_new, y_pred, average='macro') 
recall = recall_score(y_test_new, y_pred, average='macro')

print("acc: " + str(acc))
print("pre: " + str(pre))
print("recall: " + str(recall))
# Out:
# acc: 0.9260416666666667
# pre: 0.9298437244828189
# recall: 0.9259579457986243

# %% [markdown]
# ### 保存训练的历史记录，方便以后再次画图

# %%
# 保存训练的历史记录pickle.dump()
import pickle

history_filename = "AD-CN-MCI-SE-Denseblock-SE.json"
with open(history_filename, "wb") as file_json:
    pickle.dump(history.history, file_json)

# %%
# 读取保存的训练历史记录
with open(history_filename, "rb") as file_json:
    history_file = pickle.load(file_json)

# %%
def accuracy_lr_loss_plot_file (history_file):
    fig = plt.figure(figsize=(15,10))
    
    plt.subplot(221)
    plt.plot(history_file["loss"], "bo--", label="loss")
    plt.plot(history_file["val_loss"], "ro--", label = "val_loss")
    plt.title("Training Data Loss")
    plt.xlabel("Number of epochs")
    plt.ylabel("loss")
    plt.grid()
    plt.legend()
    plt.tight_layout()
    
    plt.subplot(222)
    plt.plot(history_file["accuracy"], 'bo--', label="accuracy")
    plt.plot(history_file['val_accuracy'], 'ro--', label="val_accuracy")
    plt.title("Training Data Accuracy Measurements")
    plt.xlabel("Number of epochs")
    plt.ylabel("Accuracy")
    plt.grid()
    plt.legend()
    plt.tight_layout()
    
   
    
    plt.show()

# %%
accuracy_lr_loss_plot_file(history_file)
